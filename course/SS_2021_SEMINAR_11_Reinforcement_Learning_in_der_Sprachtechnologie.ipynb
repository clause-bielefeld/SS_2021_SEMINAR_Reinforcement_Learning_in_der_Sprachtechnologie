# %% [markdown]
# # SS 2021 SEMINAR 11 Reinforcement Learning in der Sprachtechnologie
# ## Reinforcement Learning Based Speech Agents I

# %% [markdown]
# ### Announcements
#
# #### Grading
#
# * Grading: procentual division: 50/50  -> 50/16/16/16
#
# #### Homework
#
# * DEADLINE: Today, JUNE 23th
#
# #### Today
#
# * Initial Example on RL based Speech Agents
#
# * General First Step when RL is put on a NLP problem -> REINFORCE/Policy Gradient Methods
#
# * Putting RL on-top of Supervised Learning Based Speech Agents: Self-Critical Sequence Training
#
# ***

# %% [markdown]
# ### A) Paper Presentation I: Nazia

# %% [markdown]
# ### Title: Generating Visual Explanations
#
# ##### Link:
# [Generating Visual Explanations](https://www.semanticscholar.org/paper/Generating-Visual-Explanations-Hendricks-Akata/ecf551d532d0e9cfb252a1bea04d14db620bc488)
#
# ##### Summary:
# The main goal is to produce textual explanations for the classification decision of a visual system (e.g., image classification) to a non-expert user using current language and vision model (here, image captioning model). These textual explanations provide rationale for the prediction made by an AI system and plays a crucial role in developing user trust. The paper proposes a loss function based on samping and reinforcement learning to generate class-relevant descriptions (explanations).
#
# ##### Task:
# To generate a textual explanation along with a classification decision for a fine-grained visual system (bird-image classification).
# For example, predicted class label (“This is a warbler...”) and then an explanation conjunction (e.g., “because”) followed by the explantory text sentence fragment produced by the model (“this small bird has brown wings and yellow pointy beak”).
#
# ![alt_text](https://d3i71xaburhd42.cloudfront.net/7e6eb3091f84c10e65921e708f67f69c299ebd10/2-Figure1-1.png "")
#
# ##### Data:
# + Image data: CUB-200-2011 data consists of 200 north american bird species
# + Language data: Five sentence-level descriptions for each image
#
# ##### Visual Explanation Model:
# * **Fine-grained image classifier**
#     + Compact bilinear fine-grained clasification model pre-trained on CUB dataset
#
# * **Language generation model/ Visual description model (image captioning)**
#     + Encoder: CNN extracts high-level visual features
#     + Decoder: Two stacked LSTMs conditioned on visual features as well as category label
#
# * **Sentence classifier**
#     + Bird category classification using image descriptions
#
# ![alt text](https://d3i71xaburhd42.cloudfront.net/7e6eb3091f84c10e65921e708f67f69c299ebd10/5-Figure3-1.png "")
#
# * **Loss functions**
# * Relevance loss
#     + To train the model to predict each word in ground truth sentence
#     + Produce sentences which corresponds more to the image content
#
# * Discriminative loss based on **Reinforcement learning paradigm**
#     + Based on REINFORCE algorithm
#     + Sampling category relevant descriptions using Monte Carlo sampling method
#         + __State space__: {image features, category label features}
#         + __Action space__: set of most relevant sentence for 200 bird categories
#         + __Policy__: to be able to sample a sentence most relevant to the predicted bird category (using model's softmax output) so as to maximize reward
#         + __Reward__: high reward if predicted image classifier and sentence classifier outcome is same
#         + [Helpful post](https://www.analyticsvidhya.com/blog/2020/11/reinforce-algorithm-taking-baby-steps-in-reinforcement-learning/)
#
# * The overall loss is a linear combination of the relevance and discriminative loss.
#
# ##### Results:
# * **Metrics**
#     + Automatic metrics (CIDEr and METEOR)
#     + Human Evaluation
#     + Higher METEOR and CIDEr scores should mean produced sentences are more image and class relevant.
#
# ![alt_text](https://d3i71xaburhd42.cloudfront.net/7e6eb3091f84c10e65921e708f67f69c299ebd10/10-Table1-1.png "")
#
# * **Models (comparison of explanation, baselines and ablations)**
#     + Definition: Using only category label as input
#     + Description: Using only image features as input
#     + Explanation Label: not trained with discriminative loss
#     + Explanation Dis : not conditioned on category label
#     + Explanation: using both image features and category label as input
#
# * **Findings**
#     + Explanation model has higher METEOR and CIDEr scores than baselines
#     + Explanation model has higher class similarity score
#     + Explanation model has lower class rank which suggests that generated sentences closely resemble the correct class
#     + Also, for human evaluation, explanation model has lower rank. All models conditioned on label has lower rank
#
#
# ##### Critical Discussion:
# * ++ Logical structure
# * ++ Natural language explanation module trained jointly with classification model. More intuitive to non-expert users of the system
# * -- Class similarity metric is not entrely a proper measure. Higher CIDEr scores can also mean that overall sentences are better; even when they are not class relevant
# * -- Missing information of a few model parameters, could be important for reproducibility
#
# ***

# %% [markdown]
# ### Discussion
#
#
#
# ***

# %% [markdown]
# ## B) Theory

# %% [markdown]
#  **Putting RL on top of Supervised ML Problems in NLP**

# %% [markdown]
# Okay, what do we have so far from an NLP perspective:
#
# ### Sequence2Sequence Models
#
# The idea was to model language as a sequence of tokens and to produce language models, whereby a language model is a model that getting a token is able to predict the next token.
#
# * SOTA: RNN based
#
# <img src="https://miro.medium.com/max/3972/1*1JcHGUU7rFgtXC_mydUA_Q.jpeg" width="500"/>
#
# * SOTA: Transformer based
#
# <img src="https://jalammar.github.io/images/t/transformer_resideual_layer_norm_3.png" width="500"/>
#
# ***
#
# ### Word Embeddings
#
# For having better, more semantically representing representations for tokens, we use word embeddings
#
# <img src="https://ruder.io/content/images/size/w2000/2016/04/word_embeddings_colah.png" width="500"/>
#
# ***
#
# ### Connection of RL and NLP
#
# How can we connect these ideas of supervised learning based NLP approaches with Reinforcement Learning?
#
# * The connection of RL and NLP happens in the **Seq2Seq-Training Approach**
#
# * RECAP: How do we train **supervised?**
# * => **LOG LIKELIHOOD TRAINING = given this input (and this past of length n steps), what is the most likely output token**
#
# <img src="https://miro.medium.com/max/1838/1*ooyV-A6O7so_EhvkGZMZ3g.png" width="500"/>
#
# * WHY is that NOT really satisfying?
# * => If we take a closer look, the supervised approach is treated as a **STEP WISE CLASSIFICATION PROBLEM**, that means for every decoding step of a sequence (e.g. a natural language sentence) we compute the log likelihood over ALL OUTPUT TOKENS (=vocabulary) and then classify the token with the highest log probability.
#
# <img src="https://miro.medium.com/max/5412/1*NKhwsOYNUT5xU7Pyf6Znhg.png" width="500"/>
#
# * OPTIMIZATION: We can train this supervised multi step classification problem based on **SGD** in combination with cross-entropy loss/log-loss.
#
# * HOW DO WE TRAIN?:
# * => it turns out that we have different possibilities to train our models, especially our DECODERS.
# * The 1. naive approach is to train the decoder based on its own output, which is called ARGMAX training, or SELF-FORCED. This leads to LONG training times.
# * To improve this => What we do is something called **TEACHER FORCING** => that means as the gold output we compute the token-wise loss against a gold sentence and **FEED THE GOLD TOKEN** as input into the decoder to produce the next token. This leads to shorter training times but leads to less robust models in inference and also the model seems to give more or less average answers and does not really adapt to the input.
# *  Solution: => is in the middle: **CURRICULUM learning** = start with teacher forcing and the more you learn the more often use the own generated outputs as inputs for the next step
#
# <img src="https://miro.medium.com/max/1078/1*lmjxIAhR3WmPKY_6bSgM1w.png" width="500"/>
#
# ***
#
# Lets have a closer look on the decoding:
#
# * DECODING:
#
# * PROBLEM 1: In decoding, we then face the problem, that there is NO GOLD TOKEN anymore and we have to use the token from the last step as input to the next step. When applying this, our model (most of the time) produces very strange utterances, because HUMANS do not produce sentences based on **what could be the most probable next token**, but more seem to have a look-ahead over the next N tokens (3-8) and then distribute the probability of the main point they want to transmit over these tokens.
#
# * PROBLEM 2: there is another problem that can appear: we have a single point of failure in decoding -> that means if we decode one token wrong it will lead our whole output sequence into the wrong direction. During the training, we haven't asked our decoder RNN to use its own output as input, so one single mistake during the generation may confuse the decoder and lead to garbage output.
#
# * SOLUTION: In practice, what we then apply is BEAM-SEARCH as a trick, to find the most suitable sentence that (hopefully) sounds nice to humans. That means we simulate an N step (most of the time between 5 and 10) look-ahead and out of these sequences we pick the sequence, that after the N steps is the most likely one.
#
# <img src="https://www.researchgate.net/profile/Basura-Fernando/publication/322582680/figure/fig2/AS:659877194113026@1534338391439/Example-of-constrained-beam-search-decoding-Each-output-sequence-must-include-the-words.png" width="500"/>
#
# * PROBLEM 3: but wait, how do we evaluate the goodness of a sentence at all?
# * => Pure LOSS is not a very good thing to optimize against, because it leads to learning things by heart and not really generalize well. Alternative: BLEU, ROUGE, (CIDER, SPICE, for image descriptions)..... As a gist: overlap metrics, weighted overlap metrics (unigram, bigram, ..), concept-graph metrics (cider, spice). These metrics allow us to compute the overlap of our output to a SET of outputs, that we know are good/solve the problem.
#
# <img src="https://slidetodoc.com/presentation_image_h/09d128ca66b95f499e3c32f2446b960e/image-43.jpg" width="500"/>
#
# If you have a novel idea for scoring: YOU'RE WELCOME :)
#
# Seems to be a lot of dirty magic going on, ha ? :)
#
# ***
#
# In fact, **curriculum learning** and **beam search** might not be the only ways to decode a sequence.
#
# This is where RL joins the game.
#
# * QUESTION: How to form the DECODING into an RL problem?
#
# * FIRST STEP: The first thing to note is that our decoder outputs the **probability distribution at every step**, which is very similar to policy gradient models. From this perspective, our decoder could be seen as an agent trying to decide which token to produce at every step.
#
# * ADVANTAGES (of framing decoding like this):
#
# * 1. GOAL DIRECTED: = convey a certain information. solution = sequence of tokens = sentence => multiple possible solutions/sentences that lead to the goal. (e.g. there are many possible replies to 'how are you?') By optimizing the log-likelihood objective/supervised learning, our model will try to learn some **average of all those replies**, but the average of the phrases might mostly be **'I'm fine, thanks'!** and will not necessarily be a meaningful phrase. By returning the probability distribution and sampling the next token from it, our agent potentially could learn how to produce all possible variants, instead of learning some averaged answer.
#
# * 2. SCORE DRIVEN: The second benefit is optimizing the objective that we care about. In log-likelihood training, we're minimizing the cross-entropy between the produced tokens and tokens from the reference, but in machine translation, and many other NLP problems, we don't really care about log-likelihood: we want to maximize the BLEU score of the produced sequence. Unfortunately, the BLEU score is not differentiable, so we can't backpropagate on it. However, policy gradient methods, such as REINFORCE (Policy Gradients—an Alternative) work even when the reward is not differentiable: we just push up the probabilities of successful episodes and decrease the worse ones.
#
# * 3. SAMPLING: The third advantage we can exploit is in the fact that our sequence generation process is defined by us and we know its internals. By introducing stochasticity into the process of decoding, we can repeat the decoding process several times, gathering different decoding scenarios from the single training sample. This can be beneficial when our training dataset is limited, which is almost always the case. This can be useful in BOOTSTRAPPING our models for generating our own training data.
#
# ***
# ***
#
# EXCURSION: POLICY GRADIENT METHODS IN A NUTSHELL
#
# We need an algorithm , that allows us to estimate the goodness of a generated sequence (e.g a sentence) and then iteratively adapt to get better in generating new sequences.
#
# There is an algorithm that solves this sequence generation problem: REINFORCE.
#
# REINFORCE as opposed to e.g. Q-Learning is a **Policy Gradient Method**. The idea behind value-based methods like q-learning was to evaluate every ACTION in every STATE due to it's **goodness to the overall return** and then in every state choose the ACTION with the highest Q-Value.
#
# We therefore can say, that in Q-Learning we do not build up a policy, merely we build up a Q-Table/Q-Function and **USE THE Q-TABLE/FUNCTION** in a **GREEDY WAY** (by picking always the action with the highest q-value) to **EXTRACT THE (OPTIMAL) POLICY**.
#
# <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2019/04/Screenshot-2019-04-16-at-5.46.01-PM.png" width="500"/>
#
# In policy gradient methods we follow a different approach:
#
# * We directly build up a policy, which is a FUNCTION that takes in a state and returns (a probability distribution over) ACTION(S)
#
# <img src="https://mohitd.github.io/images/deep-rl-policy-methods/policy-network.svg" width="500"/>
#
# * WE update the parameters of our current policy with the gradient of the **expected return in an EPISODE** towards the policy pi we are following
#
# * WE can take the gradient based on this by maximizing the reward of our trajectory => this is like moving the direction of the highest reward. instead moving in the direction of the negative gradient, like we want to do in gradient descent and in most supervised learning tasks, we now use gradient ascent and move into the direction of the positive gradient.
#
# * FUNDAMENTAL: The base for policy gradient methods is the **policy gradient theorem**, which states that this update will converge to the optimal policy.
#
# * REMEMBER: a policy induces a trajectory distribution (= for every state it induces a sequence of actions towards the goal state, this sequence can be deterministic or stochastic), therefore a policy also induces a reward distributions (over the different trajectories).
#
# This looks like this:
#
# <img src="https://miro.medium.com/max/3464/1*zkOBQ9Izq28yXCANTmdKtA.png" width="500"/>
#
# Explained in a few words the idea is:
# 1. come up with a random trajectory as your baseline. (e.g. the ARGMAX baseline)
# 2. compute the reward of that trajectory.
# 3. come up with another trajectory.
# 4. compute the reward of that trajectory.
# 5. compute the gradients towards the baseline for the rewards in every step (=averaging over the batch, in this case of size 2)
# 6. apply gradient ascent until convergence
#
# This can be done not only over two trajectories, but also over a batch of N trajectories and then it can be averaged, analogously to what we do in supervised learning.
#
# <img src="https://static.horiba.com/fileadmin/Horiba/_processed_/a/2/csm_Validated_Performance_Logo_MM_Picture_fr_751ed2e239.png" width="500"/>
#
# In contrast to supervised learning, where we compute the difference of our output to the gold standard over n examples and then average that and move into the direction of the negative gradient to reach the minimum distance, in policy gradient methods, we compute the return over n trajectories and than average that and move into the direction of the gradient to reach the maximum reward.
#
# Over the training time, this ensures, that for every timestep, the actions that were GOOD(=produced good returns) become more likely under the current policy that we are building up.
#
# Applied to DEEP REINFORCEMENT LEARNING policy gradients in action look like this:
#
# 1. we start with a randomly initialized neural network which we call our policy network.
# 2. we feed our policy network a STATE REPRESENTATION of the current TIME STEP T and it produces a DISTRIBUTION over ACTIONS as output,
# 3. Due to our exploration-exploitation trade-off we sample from this distribution to get the action for that state and timestep,
# 4. we collect a REWARD for that state-action sequence at timestep T,
# 5. we get the next state, next reward, next state, next reward -> we collect the SEQUENCE of (s,a,r,s') as a trajectory.
# 6. We than take the hole SEQUENCE of steps as an EXPERIENCE and apply the policy gradient theorem to our batch of experiences by using the accumulated reward of the whole episode as our SCORING function. This makes it also suitable for sparse reward problems.
# 7. We do this until convergence, and the theorem proves, that over time, the actions that lead to negative rewards are slowly going to be filtered out and for every state, the actions that lead to higher returns at the end of an episode are becoming more likeli.
#
# <img src="https://abhishm.github.io/assets/images/2017-05-26-policy-gradient-with-RNN/mlp_policy.png" width="500"/>
#
# IMPORTANT: The difference to DEEP Q LEARNING is, that in a Deep Q Network, we learn THE Q-VALUE DISTRIBUTION over the ACTIONS for every state. In contrast, in a POLICY GRADIENT NETWORK, we learn the PROBABILITY DISTRIBUTION over the ACTIONS for every state.
#
# That means, we are optimizing towards different things! (and our updates are based on different things, in deep q learning we update towards the expected return of the action in the next state (as an approximation of the RETURN), in a policy gradient network, we update to the SEQUENCE of actions that lead to the highest reward.
#
# DISADVANTAGES:
#
# * CREDIT ASSIGNMENT PROBLEM: the problem of policy gradient methods is that it uses the accumulated reward at the end of an episode to evaluate a trajectory. This is especially suitable in case of sparse reward problems, BUT it thereby also assumes, that in an episode e.g. of the game pong, where an agent LOST the game, ALL ACTIONS must have been bad actions... which is obviously NOT ALWAYS THE CASE! This leads us to the CREDIT ASSIGNMENT PROBLEM, which is the problem of assigning rewards to specific actions. (=which action caused the reward or what are the (combination) of actions that lead to the reward). In practice this leads to the case that algorithms need a LOT of episodes as EXAMPLES for learning, which means a high training time (sample efficiency).
#
# * REWARD SHAPING: Sparse Reward Problems lead to REWARD SHAPING = introducing additional rewards at different time stamps to overcome the sparcity. This leads to different approaches like CURIOSITY or INTRINSIC MOTIVATION, where agents are motivated for e.g. finding new states they never saw before. BUT artificially created reward functions during reward shaping can lead to a lot of problems when done wrong (e.g. an agent that tries to trick the intermediate reward and gets addicted to intermediate rewards and does NOT reach the final reward). That means, that training in sparse reward settings is very hard but at the same time reward shaping is also very tricky crucial for success.
#
#
# ***
#
# ***
#
# OKAY, how to apply all this now to a Seq2Seq generation problem in NLP?
#
# SOLUTION:
#
# REINFORCE for seq2seq in a nutshell:
#
# In practice, REINFORCE for seq2seq training could be written as the following algorithm:
#
# 1. For every dialogue input in the dataset, obtain the encoded representation using e.g. an RNN
# 2. Initialize the current token with the special begin token: T = 'BEG'
# 3. Initialize the output sequence with the empty sequence: Out = []
# 4. While END_TOKEN not reached:
#     * Get the probability distribution of the tokens and the new hidden state, passing the current token and the hidden state to the decoder
#     * Sample the output token from the probability distribution
#     * Remember the probability distribution
#     * Append the output token to the output sequence
#     * Set the current token to the last output token
# 5. Calculate BLEU or another metric between Out and the reference sequences: Q = BLEU(Out, Outref)
# 6. Estimate the gradients
# 7. update the model using SGD
# 8. repeat until convergence
#
# * This process is called **SELF-CRITICAL SEQUENCE TRAINING**.
#
# <img src="https://miro.medium.com/max/3200/1*twlT4no5KP5Bw3TiDOf1kw.png" width="500"/>
#
# <br>
#
# <img src="https://planspace.org/20171114-deep_rl/img/planning2.png" width="500"/>
#
# <br>
#
# * DISADVANTAGES:
# * VOCABULARY SIZE: vast amount of output sequences that are possible => this makes it to  a sparse reward problem. It's almost useless to train from scratch. Even for simple dialogues, the output sequence usually has at least five words, each taken from a dictionary of several thousand words. The number of different phrases of size five with a dictionary of 1,000 words equals 51000, which is slightly less than 10700. So, the probability of obtaining the correct reply in the beginning of the training (when our weights for both the encoder and decoder are random) is negligibly small.
#
# * ADVANTAGES:
# * SEQUENCE SELECTION: Better handling of multiple target sequences. For example, 'hi' could be replied with 'hi, hello, not interested', or something else. The RL point of view is to treat our decoder as a process of selecting actions when every action is a token to be generated, which fits better to the problem.
#
# * BLEU-DIRECTED: Optimizing the BLEU score directly instead of cross-entropy loss. Using the BLEU score for the generated sequence as a gradient scale, we can push our model toward the successful sequences and decrease the probability of unsuccessful ones.
#
# * SAMPLING: By repeating the decoding process, we can generate more episodes to train on, which will lead to better gradient estimation.
#
# * SOLUTION:
# * => Combine the best of both worlds => Use Curriculum Learning (at the beginning teacher forcing, then more and more self-forcing) and then switch to REINFORCE to fine tune the model
#
# * PHILOSOPHICAL ASPECT: This is also extremely interesting from a philosophical stand-point and might be the case why TEACHERS and TEACHING might be useful in a group of agents and even through generations of agents. In general, this could be seen as a uniform approach to complex RL problems, when a large action space makes it infeasible to start with a randomly behaving agent, as the chance of such an agent randomly reaching the goal is negligible. => TEACHERS are used to BOOTSTRAP new agents quickly to a certain level until they can REINFORCE themselves to find the best solutions. Sounds like the real world, ha ?

# %% [markdown]
# ## C) Practice
#
# How can we implement **SELF-CRITICAL-SEQUENCE-TRAINING** in python?
#
# We already know the supervised-learning based dialogue agent approach from the last seminar.
#
# Starting from this model, we put our REINFORCE algorithm on top of the supervised learning based approach.
#
# This helps us in selecting better sounding sequences and works as an alternative to BEAM-SEARCH decoding.
#
# I'm basing my examples on the book of Maxim Lapan: https://www.amazon.de/-/en/Maxim-Lapan/dp/1838826998

# %%
# DATA PREPROCESSING
"""
Cornel Movies Dialogs Corpus
https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html
"""
import os
import logging

# UTILS
import string
from nltk.translate import bleu_score
from nltk.tokenize import TweetTokenizer

def calc_bleu_many(cand_seq, ref_sequences):
    sf = bleu_score.SmoothingFunction()
    return bleu_score.sentence_bleu(ref_sequences, cand_seq,
                                    smoothing_function=sf.method1,
                                    weights=(0.5, 0.5))


def calc_bleu(cand_seq, ref_seq):
    return calc_bleu_many(cand_seq, [ref_seq])


def tokenize(s):
    return TweetTokenizer(preserve_case=False).tokenize(s)


def untokenize(words):
    to_pad = lambda t: not t.startswith("'") and \
                       t not in string.punctuation
    return "".join([
        (" " + i) if to_pad(i) else i
        for i in words
    ]).strip()


# CORNELL MOVIE DATASET DIALOGUE LOADERS
log = logging.getLogger("cornell")
DATA_DIR = "data/"
SEPARATOR = "+++$+++"

def load_dialogues(data_dir=DATA_DIR, genre_filter=''):
    """
    Load dialogues from cornell data
    :return: list of list of list of words
    """
    movie_set = None
    if genre_filter:
        movie_set = read_movie_set(data_dir, genre_filter)
        log.info("Loaded %d movies with genre %s", len(movie_set), genre_filter)
    log.info("Read and tokenise phrases...")
    lines = read_phrases(data_dir, movies=movie_set)
    log.info("Loaded %d phrases", len(lines))
    dialogues = load_conversations(data_dir, lines, movie_set)
    return dialogues


def iterate_entries(data_dir, file_name):
    with open(os.path.join(data_dir, file_name), "rb") as fd:
        for l in fd:
            l = str(l, encoding='utf-8', errors='ignore')
            yield list(map(str.strip, l.split(SEPARATOR)))


def read_movie_set(data_dir, genre_filter):
    res = set()
    for parts in iterate_entries(data_dir, "movie_titles_metadata.txt"):
        m_id, m_genres = parts[0], parts[5]
        if m_genres.find(genre_filter) != -1:
            res.add(m_id)
    return res


def read_phrases(data_dir, movies=None):
    res = {}
    for parts in iterate_entries(data_dir, "movie_lines.txt"):
        l_id, m_id, l_str = parts[0], parts[2], parts[4]
        if movies and m_id not in movies:
            continue
        tokens = tokenize(l_str)
        if tokens:
            res[l_id] = tokens
    return res


def load_conversations(data_dir, lines, movies=None):
    res = []
    for parts in iterate_entries(data_dir, "movie_conversations.txt"):
        m_id, dial_s = parts[2], parts[3]
        if movies and m_id not in movies:
            continue
        l_ids = dial_s.strip("[]").split(", ")
        l_ids = list(map(lambda s: s.strip("'"), l_ids))
        dial = [lines[l_id] for l_id in l_ids if l_id in lines]
        if dial:
            res.append(dial)
    return res


def read_genres(data_dir):
    res = {}
    for parts in iterate_entries(data_dir, "movie_titles_metadata.txt"):
        m_id, m_genres = parts[0], parts[5]
        l_genres = m_genres.strip("[]").split(", ")
        l_genres = list(map(lambda s: s.strip("'"), l_genres))
        res[m_id] = l_genres
    return res

# %%
# PREPROCESSING
import collections
import os
import sys
import logging
import itertools
import pickle

UNKNOWN_TOKEN = '#UNK'
BEGIN_TOKEN = "#BEG"
END_TOKEN = "#END"
MAX_TOKENS = 20
MIN_TOKEN_FEQ = 10
SHUFFLE_SEED = 5871

EMB_DICT_NAME = "emb_dict.dat"
EMB_NAME = "emb.npy"

log = logging.getLogger("data")


def save_emb_dict(dir_name, emb_dict):
    with open(os.path.join(dir_name, EMB_DICT_NAME), "wb") as fd:
        pickle.dump(emb_dict, fd)


def load_emb_dict(dir_name):
    with open(os.path.join(dir_name, EMB_DICT_NAME), "rb") as fd:
        return pickle.load(fd)


def encode_words(words, emb_dict):
    """
    Convert list of words into list of embeddings indices, adding our tokens
    :param words: list of strings
    :param emb_dict: embeddings dictionary
    :return: list of IDs
    """
    res = [emb_dict[BEGIN_TOKEN]]
    unk_idx = emb_dict[UNKNOWN_TOKEN]
    for w in words:
        idx = emb_dict.get(w.lower(), unk_idx)
        res.append(idx)
    res.append(emb_dict[END_TOKEN])
    return res


def encode_phrase_pairs(phrase_pairs, emb_dict, filter_unknows=True):
    """
    Convert list of phrase pairs to training data
    :param phrase_pairs: list of (phrase, phrase)
    :param emb_dict: embeddings dictionary (word -> id)
    :return: list of tuples ([input_id_seq], [output_id_seq])
    """
    unk_token = emb_dict[UNKNOWN_TOKEN]
    result = []
    for p1, p2 in phrase_pairs:
        p = encode_words(p1, emb_dict), encode_words(p2, emb_dict)
        if unk_token in p[0] or unk_token in p[1]:
            continue
        result.append(p)
    return result


def group_train_data(training_data):
    """
    Group training pairs by first phrase
    :param training_data: list of (seq1, seq2) pairs
    :return: list of (seq1, [seq*]) pairs
    """
    groups = collections.defaultdict(list)
    for p1, p2 in training_data:
        l = groups[tuple(p1)]
        l.append(p2)
    return list(groups.items())


def iterate_batches(data, batch_size):
    assert isinstance(data, list)
    assert isinstance(batch_size, int)

    ofs = 0
    while True:
        batch = data[ofs*batch_size:(ofs+1)*batch_size]
        if len(batch) <= 1:
            break
        yield batch
        ofs += 1


def load_data(genre_filter, max_tokens=MAX_TOKENS, min_token_freq=MIN_TOKEN_FEQ):
    dialogues = load_dialogues(genre_filter=genre_filter)
    if not dialogues:
        log.error("No dialogues found, exit!")
        sys.exit()
    log.info("Loaded %d dialogues with %d phrases, generating training pairs",
             len(dialogues), sum(map(len, dialogues)))
    phrase_pairs = dialogues_to_pairs(dialogues, max_tokens=max_tokens)
    log.info("Counting freq of words...")
    word_counts = collections.Counter()
    for dial in dialogues:
        for p in dial:
            word_counts.update(p)
    freq_set = set(map(lambda p: p[0], filter(lambda p: p[1] >= min_token_freq, word_counts.items())))
    log.info("Data has %d uniq words, %d of them occur more than %d",
             len(word_counts), len(freq_set), min_token_freq)
    phrase_dict = phrase_pairs_dict(phrase_pairs, freq_set)
    return phrase_pairs, phrase_dict


def phrase_pairs_dict(phrase_pairs, freq_set):
    """
    Return the dict of words in the dialogues mapped to their IDs
    :param phrase_pairs: list of (phrase, phrase) pairs
    :return: dict
    """
    res = {UNKNOWN_TOKEN: 0, BEGIN_TOKEN: 1, END_TOKEN: 2}
    next_id = 3
    for p1, p2 in phrase_pairs:
        for w in map(str.lower, itertools.chain(p1, p2)):
            if w not in res and w in freq_set:
                res[w] = next_id
                next_id += 1
    return res


def dialogues_to_pairs(dialogues, max_tokens=None):
    """
    Convert dialogues to training pairs of phrases
    :param dialogues:
    :param max_tokens: limit of tokens in both question and reply
    :return: list of (phrase, phrase) pairs
    """
    result = []
    for dial in dialogues:
        prev_phrase = None
        for phrase in dial:
            if prev_phrase is not None:
                if max_tokens is None or (len(prev_phrase) <= max_tokens and len(phrase) <= max_tokens):
                    result.append((prev_phrase, phrase))
            prev_phrase = phrase
    return result


def decode_words(indices, rev_emb_dict):
    return [rev_emb_dict.get(idx, UNKNOWN_TOKEN) for idx in indices]


def trim_tokens_seq(tokens, end_token):
    res = []
    for t in tokens:
        res.append(t)
        if t == end_token:
            break
    return res


def split_train_test(data, train_ratio=0.95):
    count = int(len(data) * train_ratio)
    return data[:count], data[count:]

# %%
# MODEL
import numpy as np

import torch
import torch.nn as nn
import torch.nn.utils.rnn as rnn_utils
import torch.nn.functional as F

HIDDEN_STATE_SIZE = 512
EMBEDDING_DIM = 50


class PhraseModel(nn.Module):
    def __init__(self, emb_size, dict_size, hid_size):
        super(PhraseModel, self).__init__()

        self.emb = nn.Embedding(
            num_embeddings=dict_size, embedding_dim=emb_size)
        self.encoder = nn.LSTM(
            input_size=emb_size, hidden_size=hid_size,
            num_layers=1, batch_first=True)
        self.decoder = nn.LSTM(
            input_size=emb_size, hidden_size=hid_size,
            num_layers=1, batch_first=True)
        self.output = nn.Linear(hid_size, dict_size)

    def encode(self, x):
        _, hid = self.encoder(x)
        return hid

    def get_encoded_item(self, encoded, index):
        # For RNN
        # return encoded[:, index:index+1]
        # For LSTM
        return encoded[0][:, index:index+1].contiguous(), \
               encoded[1][:, index:index+1].contiguous()

    def decode_teacher(self, hid, input_seq):
        # Method assumes batch of size=1
        out, _ = self.decoder(input_seq, hid)
        out = self.output(out.data)
        return out

    def decode_one(self, hid, input_x):
        out, new_hid = self.decoder(input_x.unsqueeze(0), hid)
        out = self.output(out)
        return out.squeeze(dim=0), new_hid

    def decode_chain_argmax(self, hid, begin_emb, seq_len,
                            stop_at_token=None):
        """
        Decode sequence by feeding predicted token to the net again. Act greedily
        """
        res_logits = []
        res_tokens = []
        cur_emb = begin_emb

        for _ in range(seq_len):
            out_logits, hid = self.decode_one(hid, cur_emb)
            out_token_v = torch.max(out_logits, dim=1)[1]
            out_token = out_token_v.data.cpu().numpy()[0]

            cur_emb = self.emb(out_token_v)

            res_logits.append(out_logits)
            res_tokens.append(out_token)
            if stop_at_token is not None:
                if out_token == stop_at_token:
                    break
        return torch.cat(res_logits), res_tokens

    def decode_chain_sampling(self, hid, begin_emb, seq_len,
                              stop_at_token=None):
        """
        Decode sequence by feeding predicted token to the net again.
        Act according to probabilities
        """
        res_logits = []
        res_actions = []
        cur_emb = begin_emb

        for _ in range(seq_len):
            out_logits, hid = self.decode_one(hid, cur_emb)
            out_probs_v = F.softmax(out_logits, dim=1)
            out_probs = out_probs_v.data.cpu().numpy()[0]
            action = int(np.random.choice(
                out_probs.shape[0], p=out_probs))
            action_v = torch.LongTensor([action])
            action_v = action_v.to(begin_emb.device)
            cur_emb = self.emb(action_v)

            res_logits.append(out_logits)
            res_actions.append(action)
            if stop_at_token is not None:
                if action == stop_at_token:
                    break
        return torch.cat(res_logits), res_actions


def pack_batch_no_out(batch, embeddings, device="cpu"):
    assert isinstance(batch, list)
    # Sort descending (CuDNN requirements)
    batch.sort(key=lambda s: len(s[0]), reverse=True)
    input_idx, output_idx = zip(*batch)
    # create padded matrix of inputs
    lens = list(map(len, input_idx))
    input_mat = np.zeros((len(batch), lens[0]), dtype=np.int64)
    for idx, x in enumerate(input_idx):
        input_mat[idx, :len(x)] = x
    input_v = torch.tensor(input_mat).to(device)
    input_seq = rnn_utils.pack_padded_sequence(
        input_v, lens, batch_first=True)
    # lookup embeddings
    r = embeddings(input_seq.data)
    emb_input_seq = rnn_utils.PackedSequence(
        r, input_seq.batch_sizes)
    return emb_input_seq, input_idx, output_idx


def pack_input(input_data, embeddings, device="cpu"):
    input_v = torch.LongTensor([input_data]).to(device)
    r = embeddings(input_v)
    return rnn_utils.pack_padded_sequence(
        r, [len(input_data)], batch_first=True)


def pack_batch(batch, embeddings, device="cpu"):
    emb_input_seq, input_idx, output_idx = pack_batch_no_out(
        batch, embeddings, device)

    # prepare output sequences, with end token stripped
    output_seq_list = []
    for out in output_idx:
        s = pack_input(out[:-1], embeddings, device)
        output_seq_list.append(s)
    return emb_input_seq, output_seq_list, input_idx, output_idx


def seq_bleu(model_out, ref_seq):
    model_seq = torch.max(model_out.data, dim=1)[1]
    model_seq = model_seq.cpu().numpy()
    return calc_bleu(model_seq, ref_seq)

# %%
# TRAINING I: Supervised Curriculum Learning (Teacher Forcing + Argmax/Self-Forcing)
import os
import random
import argparse
import logging
import numpy as np

import torch
import torch.optim as optim
import torch.nn.functional as F

SAVES_DIR = "data"

BATCH_SIZE = 32
LEARNING_RATE = 1e-3
MAX_EPOCHES = 100

log = logging.getLogger("train")

TEACHER_PROB = 0.5

def run_test(test_data, net, end_token, device="cpu"):
    bleu_sum = 0.0
    bleu_count = 0
    for p1, p2 in test_data:
        input_seq = pack_input(p1, net.emb, device)
        enc = net.encode(input_seq)
        _, tokens = net.decode_chain_argmax(
            enc, input_seq.data[0:1], seq_len=MAX_TOKENS,
            stop_at_token=end_token)
        bleu_sum += calc_bleu(tokens, p2[1:])
        bleu_count += 1
    return bleu_sum / bleu_count


# run training
fmt = "%(asctime)-15s %(levelname)s %(message)s"
logging.basicConfig(format=fmt, level=logging.INFO)
data_genre = "comedy"
cuda_available = True
name_of_the_run = 'comedy_conversations'
device = torch.device("cuda" if cuda_available else "cpu")
saves_path = os.path.join(SAVES_DIR, name_of_the_run)
os.makedirs(saves_path, exist_ok=True)

phrase_pairs, emb_dict = load_data(genre_filter=data_genre)
log.info("Obtained %d phrase pairs with %d uniq words", len(phrase_pairs), len(emb_dict))

save_emb_dict(saves_path, emb_dict)
end_token = emb_dict[END_TOKEN]

train_data = encode_phrase_pairs(phrase_pairs, emb_dict)
rand = np.random.RandomState(SHUFFLE_SEED)
rand.shuffle(train_data)
log.info("Training data converted, got %d samples", len(train_data))
train_data, test_data = split_train_test(train_data)
log.info("Train set has %d phrases, test %d", len(train_data), len(test_data))

net = PhraseModel(emb_size=EMBEDDING_DIM, dict_size=len(emb_dict), hid_size=HIDDEN_STATE_SIZE).to(device)
log.info("Model: %s", net)

optimiser = optim.Adam(net.parameters(), lr=LEARNING_RATE)
best_bleu = None

for epoch in range(MAX_EPOCHES):
    losses = []
    bleu_sum = 0.0
    bleu_count = 0
    for batch in iterate_batches(train_data, BATCH_SIZE):
        optimiser.zero_grad()
        input_seq, out_seq_list, _, out_idx = pack_batch(batch, net.emb, device)
        enc = net.encode(input_seq)

        net_results = []
        net_targets = []
        for idx, out_seq in enumerate(out_seq_list):
            ref_indices = out_idx[idx][1:]
            enc_item = net.get_encoded_item(enc, idx)
            if random.random() < TEACHER_PROB:
                r = net.decode_teacher(enc_item, out_seq)
                bleu_sum += seq_bleu(r, ref_indices)
            else:
                r, seq = net.decode_chain_argmax(enc_item, out_seq.data[0:1], len(ref_indices))
                bleu_sum += calc_bleu(seq, ref_indices)
            net_results.append(r)
            net_targets.extend(ref_indices)
            bleu_count += 1
        results_v = torch.cat(net_results)
        targets_v = torch.LongTensor(net_targets).to(device)
        loss_v = F.cross_entropy(results_v, targets_v)
        loss_v.backward()
        optimiser.step()

        losses.append(loss_v.item())
    bleu = bleu_sum / bleu_count
    bleu_test = run_test(test_data, net, end_token, device)
    log.info("Epoch %d: mean loss %.3f, mean BLEU %.3f, " "test BLEU %.3f", epoch, np.mean(losses), bleu, bleu_test)
    if best_bleu is None or best_bleu < bleu_test:
        if best_bleu is not None:
            out_name = os.path.join(
                saves_path, "pre_bleu_%.3f_%02d.dat" % (
                    bleu_test, epoch))
            torch.save(net.state_dict(), out_name)
            log.info("Best BLEU updated %.3f", bleu_test)
        best_bleu = bleu_test

    if epoch % 10 == 0:
        out_name = os.path.join(
            saves_path, "epoch_%03d_%.3f_%.3f.dat" % (
                epoch, bleu, bleu_test))
        torch.save(net.state_dict(), out_name)
# Out:
# 2021-06-23 09:15:36,536 INFO Loaded 159 movies with genre comedy
# 2021-06-23 09:15:36,539 INFO Read and tokenise phrases...
# 2021-06-23 09:15:44,560 INFO Loaded 93039 phrases
# 2021-06-23 09:15:44,628 INFO Loaded 4445 dialogues with 17107 phrases, generating training pairs
# 2021-06-23 09:15:44,635 INFO Counting freq of words...
# 2021-06-23 09:15:44,683 INFO Data has 11807 uniq words, 1442 of them occur more than 10
# 2021-06-23 09:15:44,723 INFO Obtained 8885 phrase pairs with 1441 uniq words
# 2021-06-23 09:15:44,783 INFO Training data converted, got 3116 samples
# 2021-06-23 09:15:44,783 INFO Train set has 2960 phrases, test 156
# 2021-06-23 09:15:44,831 INFO Model: PhraseModel(
#   (emb): Embedding(1441, 50)
#   (encoder): LSTM(50, 512, batch_first=True)
#   (decoder): LSTM(50, 512, batch_first=True)
#   (output): Linear(in_features=512, out_features=1441, bias=True)
# )
# 2021-06-23 09:15:57,827 INFO Epoch 0: mean loss 5.041, mean BLEU 0.165, test BLEU 0.116
# 2021-06-23 09:16:11,227 INFO Epoch 1: mean loss 4.642, mean BLEU 0.178, test BLEU 0.117
# 2021-06-23 09:16:11,246 INFO Best BLEU updated 0.117
# 2021-06-23 09:16:24,415 INFO Epoch 2: mean loss 4.556, mean BLEU 0.186, test BLEU 0.118
# 2021-06-23 09:16:24,434 INFO Best BLEU updated 0.118
# 2021-06-23 09:16:38,233 INFO Epoch 3: mean loss 4.498, mean BLEU 0.189, test BLEU 0.128
# 2021-06-23 09:16:38,253 INFO Best BLEU updated 0.128
# 2021-06-23 09:16:51,879 INFO Epoch 4: mean loss 4.428, mean BLEU 0.186, test BLEU 0.128
# 2021-06-23 09:17:05,235 INFO Epoch 5: mean loss 4.360, mean BLEU 0.193, test BLEU 0.134
# 2021-06-23 09:17:05,255 INFO Best BLEU updated 0.134
# 2021-06-23 09:17:18,293 INFO Epoch 6: mean loss 4.288, mean BLEU 0.194, test BLEU 0.127
# 2021-06-23 09:17:32,025 INFO Epoch 7: mean loss 4.267, mean BLEU 0.195, test BLEU 0.134
# 2021-06-23 09:17:45,236 INFO Epoch 8: mean loss 4.193, mean BLEU 0.200, test BLEU 0.125
# 2021-06-23 09:17:58,400 INFO Epoch 9: mean loss 4.126, mean BLEU 0.201, test BLEU 0.108
# 2021-06-23 09:18:11,933 INFO Epoch 10: mean loss 4.091, mean BLEU 0.200, test BLEU 0.103
# 2021-06-23 09:18:25,318 INFO Epoch 11: mean loss 4.017, mean BLEU 0.208, test BLEU 0.119
# 2021-06-23 09:18:38,404 INFO Epoch 12: mean loss 3.944, mean BLEU 0.213, test BLEU 0.130
# 2021-06-23 09:18:51,660 INFO Epoch 13: mean loss 3.882, mean BLEU 0.217, test BLEU 0.115
# 2021-06-23 09:19:04,996 INFO Epoch 14: mean loss 3.821, mean BLEU 0.224, test BLEU 0.133
# 2021-06-23 09:19:18,268 INFO Epoch 15: mean loss 3.764, mean BLEU 0.227, test BLEU 0.130
# 2021-06-23 09:19:31,457 INFO Epoch 16: mean loss 3.714, mean BLEU 0.230, test BLEU 0.098
# 2021-06-23 09:19:44,990 INFO Epoch 17: mean loss 3.677, mean BLEU 0.235, test BLEU 0.095
# 2021-06-23 09:19:58,093 INFO Epoch 18: mean loss 3.560, mean BLEU 0.248, test BLEU 0.094
# 2021-06-23 09:20:11,455 INFO Epoch 19: mean loss 3.532, mean BLEU 0.252, test BLEU 0.118
# 2021-06-23 09:20:24,545 INFO Epoch 20: mean loss 3.421, mean BLEU 0.259, test BLEU 0.124
# 2021-06-23 09:20:38,451 INFO Epoch 21: mean loss 3.424, mean BLEU 0.266, test BLEU 0.122
# 2021-06-23 09:20:51,993 INFO Epoch 22: mean loss 3.315, mean BLEU 0.274, test BLEU 0.119
# 2021-06-23 09:21:05,604 INFO Epoch 23: mean loss 3.266, mean BLEU 0.281, test BLEU 0.116
# 2021-06-23 09:21:19,160 INFO Epoch 24: mean loss 3.169, mean BLEU 0.292, test BLEU 0.117
# 2021-06-23 09:21:32,538 INFO Epoch 25: mean loss 3.082, mean BLEU 0.308, test BLEU 0.108
# 2021-06-23 09:21:46,107 INFO Epoch 26: mean loss 3.021, mean BLEU 0.319, test BLEU 0.108
# 2021-06-23 09:21:59,534 INFO Epoch 27: mean loss 2.935, mean BLEU 0.337, test BLEU 0.124
# 2021-06-23 09:22:12,895 INFO Epoch 28: mean loss 2.829, mean BLEU 0.355, test BLEU 0.120
# 2021-06-23 09:22:26,474 INFO Epoch 29: mean loss 2.762, mean BLEU 0.370, test BLEU 0.110
# 2021-06-23 09:22:40,341 INFO Epoch 30: mean loss 2.696, mean BLEU 0.392, test BLEU 0.111
# 2021-06-23 09:22:53,749 INFO Epoch 31: mean loss 2.529, mean BLEU 0.427, test BLEU 0.122
# 2021-06-23 09:23:07,261 INFO Epoch 32: mean loss 2.367, mean BLEU 0.460, test BLEU 0.105
# 2021-06-23 09:23:20,738 INFO Epoch 33: mean loss 2.236, mean BLEU 0.493, test BLEU 0.105
# 2021-06-23 09:23:34,244 INFO Epoch 34: mean loss 2.057, mean BLEU 0.532, test BLEU 0.102
# 2021-06-23 09:23:47,940 INFO Epoch 35: mean loss 1.923, mean BLEU 0.576, test BLEU 0.098
# 2021-06-23 09:24:01,610 INFO Epoch 36: mean loss 1.738, mean BLEU 0.628, test BLEU 0.102
# 2021-06-23 09:24:15,244 INFO Epoch 37: mean loss 1.581, mean BLEU 0.667, test BLEU 0.111
# 2021-06-23 09:24:29,212 INFO Epoch 38: mean loss 1.421, mean BLEU 0.711, test BLEU 0.108
# 2021-06-23 09:24:42,710 INFO Epoch 39: mean loss 1.213, mean BLEU 0.760, test BLEU 0.112
# 2021-06-23 09:24:56,263 INFO Epoch 40: mean loss 1.046, mean BLEU 0.789, test BLEU 0.110
# 2021-06-23 09:25:09,956 INFO Epoch 41: mean loss 0.951, mean BLEU 0.819, test BLEU 0.120
# 2021-06-23 09:25:23,572 INFO Epoch 42: mean loss 0.859, mean BLEU 0.834, test BLEU 0.118
# 2021-06-23 09:25:37,040 INFO Epoch 43: mean loss 0.726, mean BLEU 0.859, test BLEU 0.119
# 2021-06-23 09:25:50,790 INFO Epoch 44: mean loss 0.643, mean BLEU 0.875, test BLEU 0.109
# 2021-06-23 09:26:04,361 INFO Epoch 45: mean loss 0.537, mean BLEU 0.894, test BLEU 0.109
# 2021-06-23 09:26:18,234 INFO Epoch 46: mean loss 0.487, mean BLEU 0.898, test BLEU 0.113
# 2021-06-23 09:26:31,931 INFO Epoch 47: mean loss 0.400, mean BLEU 0.907, test BLEU 0.107
# 2021-06-23 09:26:45,409 INFO Epoch 48: mean loss 0.370, mean BLEU 0.911, test BLEU 0.120
# 2021-06-23 09:26:59,083 INFO Epoch 49: mean loss 0.362, mean BLEU 0.910, test BLEU 0.111
# 2021-06-23 09:27:12,511 INFO Epoch 50: mean loss 0.346, mean BLEU 0.908, test BLEU 0.116
# 2021-06-23 09:27:26,285 INFO Epoch 51: mean loss 0.329, mean BLEU 0.909, test BLEU 0.110
# 2021-06-23 09:27:39,841 INFO Epoch 52: mean loss 0.308, mean BLEU 0.907, test BLEU 0.115
# 2021-06-23 09:27:53,668 INFO Epoch 53: mean loss 0.325, mean BLEU 0.910, test BLEU 0.106
# 2021-06-23 09:28:07,489 INFO Epoch 54: mean loss 0.288, mean BLEU 0.908, test BLEU 0.114
# 2021-06-23 09:28:21,264 INFO Epoch 55: mean loss 0.286, mean BLEU 0.910, test BLEU 0.113
# 2021-06-23 09:28:34,821 INFO Epoch 56: mean loss 0.292, mean BLEU 0.909, test BLEU 0.108
# 2021-06-23 09:28:48,384 INFO Epoch 57: mean loss 0.259, mean BLEU 0.910, test BLEU 0.115
# 2021-06-23 09:29:02,012 INFO Epoch 58: mean loss 0.251, mean BLEU 0.912, test BLEU 0.114
# 2021-06-23 09:29:16,192 INFO Epoch 59: mean loss 0.273, mean BLEU 0.908, test BLEU 0.120
# 2021-06-23 09:29:29,869 INFO Epoch 60: mean loss 0.295, mean BLEU 0.904, test BLEU 0.115
# 2021-06-23 09:29:43,189 INFO Epoch 61: mean loss 0.275, mean BLEU 0.907, test BLEU 0.112
# 2021-06-23 09:29:56,940 INFO Epoch 62: mean loss 0.286, mean BLEU 0.907, test BLEU 0.112
# 2021-06-23 09:30:10,150 INFO Epoch 63: mean loss 0.258, mean BLEU 0.909, test BLEU 0.114
# 2021-06-23 09:30:23,899 INFO Epoch 64: mean loss 0.260, mean BLEU 0.909, test BLEU 0.118
# 2021-06-23 09:30:37,687 INFO Epoch 65: mean loss 0.261, mean BLEU 0.908, test BLEU 0.104
# 2021-06-23 09:30:50,956 INFO Epoch 66: mean loss 0.263, mean BLEU 0.908, test BLEU 0.116
# 2021-06-23 09:31:04,414 INFO Epoch 67: mean loss 0.258, mean BLEU 0.906, test BLEU 0.111
# 2021-06-23 09:31:17,802 INFO Epoch 68: mean loss 0.268, mean BLEU 0.905, test BLEU 0.114
# 2021-06-23 09:31:30,851 INFO Epoch 69: mean loss 0.242, mean BLEU 0.914, test BLEU 0.112
# 2021-06-23 09:31:44,187 INFO Epoch 70: mean loss 0.252, mean BLEU 0.907, test BLEU 0.115
# 2021-06-23 09:31:57,978 INFO Epoch 71: mean loss 0.260, mean BLEU 0.903, test BLEU 0.113
# 2021-06-23 09:32:11,430 INFO Epoch 72: mean loss 0.268, mean BLEU 0.904, test BLEU 0.115
# 2021-06-23 09:32:24,915 INFO Epoch 73: mean loss 0.242, mean BLEU 0.906, test BLEU 0.116
# 2021-06-23 09:32:38,358 INFO Epoch 74: mean loss 0.230, mean BLEU 0.913, test BLEU 0.121
# 2021-06-23 09:32:52,000 INFO Epoch 75: mean loss 0.229, mean BLEU 0.911, test BLEU 0.111
# 2021-06-23 09:33:05,401 INFO Epoch 76: mean loss 0.224, mean BLEU 0.910, test BLEU 0.110
# 2021-06-23 09:33:18,726 INFO Epoch 77: mean loss 0.259, mean BLEU 0.902, test BLEU 0.112
# 2021-06-23 09:33:32,070 INFO Epoch 78: mean loss 0.223, mean BLEU 0.912, test BLEU 0.108
# 2021-06-23 09:33:45,566 INFO Epoch 79: mean loss 0.249, mean BLEU 0.907, test BLEU 0.108
# 2021-06-23 09:33:59,327 INFO Epoch 80: mean loss 0.238, mean BLEU 0.906, test BLEU 0.105
# 2021-06-23 09:34:12,899 INFO Epoch 81: mean loss 0.252, mean BLEU 0.905, test BLEU 0.105
# 2021-06-23 09:34:26,072 INFO Epoch 82: mean loss 0.229, mean BLEU 0.908, test BLEU 0.107
# 2021-06-23 09:34:39,276 INFO Epoch 83: mean loss 0.225, mean BLEU 0.911, test BLEU 0.111
# 2021-06-23 09:34:52,724 INFO Epoch 84: mean loss 0.226, mean BLEU 0.910, test BLEU 0.108
# 2021-06-23 09:35:05,757 INFO Epoch 85: mean loss 0.234, mean BLEU 0.908, test BLEU 0.111
# 2021-06-23 09:35:19,213 INFO Epoch 86: mean loss 0.243, mean BLEU 0.907, test BLEU 0.115
# 2021-06-23 09:35:32,640 INFO Epoch 87: mean loss 0.241, mean BLEU 0.905, test BLEU 0.107
# 2021-06-23 09:35:46,164 INFO Epoch 88: mean loss 0.232, mean BLEU 0.910, test BLEU 0.118
# 2021-06-23 09:35:59,412 INFO Epoch 89: mean loss 0.240, mean BLEU 0.904, test BLEU 0.103
# 2021-06-23 09:36:12,917 INFO Epoch 90: mean loss 0.231, mean BLEU 0.908, test BLEU 0.113
# 2021-06-23 09:36:26,445 INFO Epoch 91: mean loss 0.215, mean BLEU 0.913, test BLEU 0.110
# 2021-06-23 09:36:39,972 INFO Epoch 92: mean loss 0.230, mean BLEU 0.908, test BLEU 0.105
# 2021-06-23 09:36:53,573 INFO Epoch 93: mean loss 0.238, mean BLEU 0.907, test BLEU 0.110
# 2021-06-23 09:37:07,214 INFO Epoch 94: mean loss 0.231, mean BLEU 0.908, test BLEU 0.120
# 2021-06-23 09:37:20,895 INFO Epoch 95: mean loss 0.211, mean BLEU 0.912, test BLEU 0.111
# 2021-06-23 09:37:34,741 INFO Epoch 96: mean loss 0.221, mean BLEU 0.911, test BLEU 0.110
# 2021-06-23 09:37:48,704 INFO Epoch 97: mean loss 0.224, mean BLEU 0.911, test BLEU 0.100
# 2021-06-23 09:38:01,953 INFO Epoch 98: mean loss 0.230, mean BLEU 0.907, test BLEU 0.108
# 2021-06-23 09:38:15,698 INFO Epoch 99: mean loss 0.232, mean BLEU 0.908, test BLEU 0.112

# %%
# Training II: Self-Critical-Sequence-Training
import os
import random
import argparse
import logging
import numpy as np

import torch
import torch.optim as optim
import torch.nn.functional as F

SAVES_DIR = "data"

BATCH_SIZE = 16
LEARNING_RATE = 5e-4
MAX_EPOCHES = 10000

log = logging.getLogger("train")


def run_test(test_data, net, end_token, device="cpu"):
    bleu_sum = 0.0
    bleu_count = 0
    for p1, p2 in test_data:
        input_seq = pack_input(p1, net.emb, device)
        enc = net.encode(input_seq)
        _, tokens = net.decode_chain_argmax(enc, input_seq.data[0:1], seq_len=MAX_TOKENS,stop_at_token=end_token)
         ref_indices = [indices[1:] for indices in p2]
        bleu_sum += calc_bleu_many(tokens, ref_indices)
        bleu_count += 1
    return bleu_sum / bleu_count


fmt = "%(asctime)-15s %(levelname)s %(message)s"
logging.basicConfig(format=fmt, level=logging.INFO)
data_genre = "comedy"
cuda_available = True 
name_of_the_run = 'comedy_conversations'
model_path = "data/comedy_conversations/epoch_090_0.908_0.113.dat"
number_of_samples_in_prob_mode = 4
disable_skip = False # Disable skipping of samples with high argmax BLEU action=store_true
device = torch.device("cuda" if cuda_available else "cpu")
saves_path = os.path.join(SAVES_DIR, name_of_the_run)
os.makedirs(saves_path, exist_ok=True)

phrase_pairs, emb_dict = load_data(genre_filter=data_genre)
log.info("Obtained %d phrase pairs with %d uniq words", len(phrase_pairs), len(emb_dict))
save_emb_dict(saves_path, emb_dict)
end_token = emb_dict[END_TOKEN]
train_data = encode_phrase_pairs(phrase_pairs, emb_dict)
rand = np.random.RandomState(SHUFFLE_SEED)
rand.shuffle(train_data)
train_data, test_data = split_train_test(train_data)
log.info("Training data converted, got %d samples", len(train_data))
train_data = group_train_data(train_data)
test_data = group_train_data(test_data)
log.info("Train set has %d phrases, test %d", len(train_data), len(test_data))

rev_emb_dict = {idx: word for word, idx in emb_dict.items()}

net = PhraseModel(emb_size=EMBEDDING_DIM, dict_size=len(emb_dict), hid_size=HIDDEN_STATE_SIZE).to(device)
log.info("Model: %s", net)

net.load_state_dict(torch.load(model_path))
log.info("Model loaded from %s, continue ""training in RL mode...", model_path)

# BEGIN token
beg_token = torch.LongTensor([emb_dict[BEGIN_TOKEN]])
beg_token = beg_token.to(device)

optimiser = optim.Adam(net.parameters(), lr=LEARNING_RATE, eps=1e-3)
batch_idx = 0
best_bleu = None
for epoch in range(MAX_EPOCHES):
    random.shuffle(train_data)
    dial_shown = False
    total_samples = 0
    skipped_samples = 0
    bleus_argmax = []
    bleus_sample = []

    for batch in iterate_batches(train_data, BATCH_SIZE):
        batch_idx += 1
        optimiser.zero_grad()
        input_seq, input_batch, output_batch = pack_batch_no_out(batch, net.emb, device)
        enc = net.encode(input_seq)

        net_policies = []
        net_actions = []
        net_advantages = []
        beg_embedding = net.emb(beg_token)

        for idx, inp_idx in enumerate(input_batch):
            total_samples += 1
            ref_indices = [indices[1:]for indices in output_batch[idx]]
            item_enc = net.get_encoded_item(enc, idx)
            r_argmax, actions = net.decode_chain_argmax(item_enc, beg_embedding, MAX_TOKENS,stop_at_token=end_token)
            argmax_bleu = calc_bleu_many(actions, ref_indices)
            bleus_argmax.append(argmax_bleu)

            if not disable_skip:
                if argmax_bleu > 0.99:
                    skipped_samples += 1
                    continue

            if not dial_shown:
                w = decode_words(inp_idx, rev_emb_dict)
                log.info("Input: %s", untokenize(w))
                ref_words = [untokenize(decode_words(ref, rev_emb_dict)) for ref in ref_indices]
                ref = " ~~|~~ ".join(ref_words)
                log.info("Refer: %s", ref)
                w = decode_words(actions, rev_emb_dict)
                log.info("Argmax: %s, bleu=%.4f", untokenize(w), argmax_bleu)

            for _ in range(number_of_samples_in_prob_mode):
                r_sample, actions = net.decode_chain_sampling(item_enc, beg_embedding,MAX_TOKENS,stop_at_token=end_token)
                sample_bleu = calc_bleu_many(actions, ref_indices)

                if not dial_shown:
                    w = decode_words(actions, rev_emb_dict)
                    log.info("Sample: %s, bleu=%.4f", untokenize(w), sample_bleu)

                net_policies.append(r_sample)
                net_actions.extend(actions)
                adv = sample_bleu - argmax_bleu
                net_advantages.extend([adv]*len(actions))
                bleus_sample.append(sample_bleu)
            dial_shown = True

        if not net_policies:
            continue

        policies_v = torch.cat(net_policies)
        actions_t = torch.LongTensor(net_actions).to(device)
        adv_v = torch.FloatTensor(net_advantages).to(device)
        log_prob_v = F.log_softmax(policies_v, dim=1)
        lp_a = log_prob_v[range(len(net_actions)), actions_t]
        log_prob_actions_v = adv_v * lp_a
        loss_policy_v = -log_prob_actions_v.mean()

        loss_v = loss_policy_v
        loss_v.backward()
        optimiser.step()

    bleu_test = run_test(test_data, net, end_token, device)
    bleu = np.mean(bleus_argmax)
    log.info("Epoch %d, test BLEU: %.3f", epoch, bleu_test)
    if best_bleu is None or best_bleu < bleu_test:
        best_bleu = bleu_test
        log.info("Best bleu updated: %.4f", bleu_test)
        torch.save(net.state_dict(), os.path.join(saves_path, "bleu_%.3f_%02d.dat" % (bleu_test, epoch)))
    if epoch % 10 == 0:
        torch.save(net.state_dict(), os.path.join(saves_path, "epoch_%03d_%.3f_%.3f.dat" % (epoch, bleu, bleu_test)))
# Out:
# 2021-06-23 09:43:28,761 INFO Loaded 159 movies with genre comedy
# 2021-06-23 09:43:28,761 INFO Read and tokenise phrases...
# 2021-06-23 09:43:36,947 INFO Loaded 93039 phrases
# 2021-06-23 09:43:37,026 INFO Loaded 4445 dialogues with 17107 phrases, generating training pairs
# 2021-06-23 09:43:37,032 INFO Counting freq of words...
# 2021-06-23 09:43:37,083 INFO Data has 11807 uniq words, 1442 of them occur more than 10
# 2021-06-23 09:43:37,124 INFO Obtained 8885 phrase pairs with 1441 uniq words
# 2021-06-23 09:43:37,183 INFO Training data converted, got 2960 samples
# 2021-06-23 09:43:37,187 INFO Train set has 2597 phrases, test 153
# 2021-06-23 09:43:37,232 INFO Model: PhraseModel(
#   (emb): Embedding(1441, 50)
#   (encoder): LSTM(50, 512, batch_first=True)
#   (decoder): LSTM(50, 512, batch_first=True)
#   (output): Linear(in_features=512, out_features=1441, bias=True)
# )
# 2021-06-23 09:43:37,236 INFO Model loaded from data/comedy_conversations/epoch_090_0.908_0.113.dat, continue training in RL mode...
# 2021-06-23 09:43:37,336 INFO Input: #BEG yes, i do. #END
# 2021-06-23 09:43:37,336 INFO Refer: what is it? #END ~~|~~ i've got to go. #END
# 2021-06-23 09:43:37,336 INFO Argmax: i've got it? #END, bleu=0.8660
# 2021-06-23 09:43:37,340 INFO Sample: i've is deal? #END, bleu=0.4472
# 2021-06-23 09:43:37,342 INFO Sample: i've got to? #END, bleu=0.8660
# 2021-06-23 09:43:37,345 INFO Sample: i've got it? #END, bleu=0.8660
# 2021-06-23 09:43:37,348 INFO Sample: what got to go. #END, bleu=0.8944
# 2021-06-23 09:43:47,906 INFO Epoch 0, test BLEU: 0.114
# 2021-06-23 09:43:47,907 INFO Best bleu updated: 0.1139
# 2021-06-23 09:43:48,239 INFO Input: #BEG no, i don't mind. #END
# 2021-06-23 09:43:48,240 INFO Refer: i know it must of been a bad experience. but it doesn't sound like it was your fault. #END
# 2021-06-23 09:43:48,240 INFO Argmax: i know it must of been a bad experience. but it doesn't sound like it was your fault., bleu=0.9512
# 2021-06-23 09:43:48,248 INFO Sample: i know it must of been a bad experience and but it's it visit #END, bleu=0.4532
# 2021-06-23 09:43:48,257 INFO Sample: i know it must of been a bad experience. but it doesn't sound like it was your fault., bleu=0.9512
# 2021-06-23 09:43:48,266 INFO Sample: i know it must of been a bad experience. but it doesn't sound it down was your fault., bleu=0.8508
# 2021-06-23 09:43:48,276 INFO Sample: i know it must of been a bad experience. but it doesn't sound like it was your fault., bleu=0.9512
# 2021-06-23 09:43:58,400 INFO Epoch 1, test BLEU: 0.117
# 2021-06-23 09:43:58,401 INFO Best bleu updated: 0.1166
# 2021-06-23 09:43:59,060 INFO Input: #BEG yes, i do. #END
# 2021-06-23 09:43:59,061 INFO Refer: what is it? #END ~~|~~ i've got to go. #END
# 2021-06-23 09:43:59,061 INFO Argmax: what got to go. #END, bleu=0.8944
# 2021-06-23 09:43:59,065 INFO Sample: i've got to go. #END, bleu=1.0000
# 2021-06-23 09:43:59,066 INFO Sample: cole. #END, bleu=0.2964
# 2021-06-23 09:43:59,069 INFO Sample: what got to be #END, bleu=0.4472
# 2021-06-23 09:43:59,072 INFO Sample: i've got it? #END, bleu=0.8660
# 2021-06-23 09:44:08,663 INFO Epoch 2, test BLEU: 0.118
# 2021-06-23 09:44:08,664 INFO Best bleu updated: 0.1184
# 2021-06-23 09:44:08,864 INFO Input: #BEG what? #END
# 2021-06-23 09:44:08,865 INFO Refer: that woman. the older woman. #END ~~|~~ nothing. #END ~~|~~ what do you mean what? #END ~~|~~ no one else knows #END ~~|~~ put them down! please make them put them down. #END ~~|~~ you heard me. where is it? #END ~~|~~ you ... #END ~~|~~ five hundred. #END ~~|~~ you're kidding. #END ~~|~~ did you know that? #END ~~|~~ nothing. #END ~~|~~ i don't know why i said it. i'm sorry. #END ~~|~~ what? #END ~~|~~ do you remember the make of the car? #END ~~|~~ how long have we known each other now? #END ~~|~~ i'm going to be sick. where's the ... #END ~~|~~ fight. you know. #END ~~|~~ what do you mean," what?" #END ~~|~~ i don't understand-- #END ~~|~~ i'll see you there. #END ~~|~~ i don't suppose you ... you do like me at all? #END ~~|~~ don't start acting hurt. #END ~~|~~ my husband took the car. will you drive me home? #END ~~|~~ you look beautiful like that. #END ~~|~~ your husband! mrs. robinson! there's something we could have a conversation about. #END ~~|~~ why does it never work out? you and ... men? #END ~~|~~ shoot to kill, i said. #END ~~|~~ will you kiss me! #END ~~|~~ is that ok? #END ~~|~~ well i'm going to ask you what you do when you go off at night. #END ~~|~~ is that what you're trying to tell me? #END ~~|~~ i've got a real feeling that this is the fellow. #END ~~|~~ i said i don't have any. #END ~~|~~ i've got to go. #END ~~|~~ goodnight! #END ~~|~~ have you gotten us a room yet? #END ~~|~~ i mean-- you didn't really think that i would do something like that. #END ~~|~~ i'll be there in an hour. #END ~~|~~ i want you to come in till i get the lights on. #END ~~|~~ will you take me home? #END ~~|~~ look. #END ~~|~~ what, what? #END ~~|~~ a hundred bucks a date. #END ~~|~~ the room number, benjamin. i think you ought to tell me that. #END ~~|~~ bob! get back in position! #END ~~|~~ i don't know. something. #END ~~|~~ uh, oh. now it's time. #END ~~|~~ look at me, ray. #END ~~|~~ i never did, benjamin. now let's-- #END ~~|~~ i just wish it was that simple. #END ~~|~~ the new star. what are you gonna name it? #END ~~|~~ my husband will be back quite late. #END ~~|~~ we're talking, mrs. robinson. we're talking. #END ~~|~~ we got to get another pilot. #END
# 2021-06-23 09:44:08,866 INFO Argmax: i don't number. back. #END, bleu=0.5774
# 2021-06-23 09:44:08,871 INFO Sample: uh, oh. now marriage- #END, bleu=0.7906
# 2021-06-23 09:44:08,876 INFO Sample: bob! get back in position! #END, bleu=1.0000
# 2021-06-23 09:44:08,882 INFO Sample: we're talking, mrs. robinson. we're talking. #END, bleu=1.0000
# 2021-06-23 09:44:08,887 INFO Sample: fight you get back in position. #END, bleu=0.7559
# 2021-06-23 09:44:19,049 INFO Epoch 3, test BLEU: 0.117
# 2021-06-23 09:44:19,136 INFO Input: #BEG yes, i do. #END
# 2021-06-23 09:44:19,137 INFO Refer: what is it? #END ~~|~~ i've got to go. #END
# 2021-06-23 09:44:19,137 INFO Argmax: i've got it? #END, bleu=0.8660
# 2021-06-23 09:44:19,140 INFO Sample: what got it?. #END, bleu=0.6325
# 2021-06-23 09:44:19,144 INFO Sample: what is it go? #END, bleu=0.7746
# 2021-06-23 09:44:19,146 INFO Sample: i've got it. #END, bleu=0.7071
# 2021-06-23 09:44:19,149 INFO Sample: i've got to go. #END, bleu=1.0000
# 2021-06-23 09:44:29,312 INFO Epoch 4, test BLEU: 0.123
# 2021-06-23 09:44:29,313 INFO Best bleu updated: 0.1230
# 2021-06-23 09:44:29,370 INFO Input: #BEG when i go? #END
# 2021-06-23 09:44:29,370 INFO Refer: oh, christ. don't tell me you've changed your mind. i already sent' em a check. #END
# 2021-06-23 09:44:29,371 INFO Argmax: oh, christ. don't tell me you've changed your mind. i already sent' em a check., bleu=0.9512
# 2021-06-23 09:44:29,380 INFO Sample: oh, christ. don't tell me you've changed your mind. i already sent' em a check., bleu=0.9512
# 2021-06-23 09:44:29,390 INFO Sample: oh, christ. don't tell me you've changed your mind. i already sent' em a check., bleu=0.9512
# 2021-06-23 09:44:29,399 INFO Sample: oh, christ. don't tell me you've changed your mind. i already sent' em a check., bleu=0.9512
# 2021-06-23 09:44:29,409 INFO Sample: oh, christ. don't tell me you've changed your mind. i already sent' em a check., bleu=0.9512
# 2021-06-23 09:44:39,368 INFO Epoch 5, test BLEU: 0.117
# 2021-06-23 09:44:39,442 INFO Input: #BEG well, what do you think? #END
# 2021-06-23 09:44:39,442 INFO Refer: i don't know, bob. what about one of those? #END ~~|~~ i think ... it ... works. #END
# 2021-06-23 09:44:39,443 INFO Argmax: i don't ... it bob works. #END, bleu=0.7559
# 2021-06-23 09:44:39,447 INFO Sample: i don't ... it bob works a #END, bleu=0.5000
# 2021-06-23 09:44:39,453 INFO Sample: i don't ... it ... works what about one of those? #END, bleu=0.9129
# 2021-06-23 09:44:39,459 INFO Sample: i don't ... it. works. about one of those? #END, bleu=0.7845
# 2021-06-23 09:44:39,466 INFO Sample: i don't ... it. works what about one of those? #END, bleu=0.8165
# 2021-06-23 09:44:49,582 INFO Epoch 6, test BLEU: 0.127
# 2021-06-23 09:44:49,582 INFO Best bleu updated: 0.1266
# 2021-06-23 09:44:49,608 INFO Input: #BEG good. so shall we leave it at that then? #END
# 2021-06-23 09:44:49,608 INFO Refer: we won't leave it, ian. not ever. #END ~~|~~ i dunno. #END
# 2021-06-23 09:44:49,609 INFO Argmax: i dunno. it, ian. not ever. #END, bleu=0.9045
# 2021-06-23 09:44:49,615 INFO Sample: i dunno. it, ian. not ever. #END, bleu=0.9045
# 2021-06-23 09:44:49,618 INFO Sample: i dunno. #END, bleu=1.0000
# 2021-06-23 09:44:49,620 INFO Sample: i dunno. #END, bleu=1.0000
# 2021-06-23 09:44:49,626 INFO Sample: i dunno. it, ian. not ever on. #END, bleu=0.7785
# 2021-06-23 09:44:59,782 INFO Epoch 7, test BLEU: 0.116
# 2021-06-23 09:45:00,204 INFO Input: #BEG are they behind us? #END
# 2021-06-23 09:45:00,205 INFO Refer: no, i don't think so ... wait. they're not but ... something is. oh my god. #END
# 2021-06-23 09:45:00,205 INFO Argmax: no, i don't think so ... wait. they're not but ... something is. #END, bleu=0.7903
# 2021-06-23 09:45:00,215 INFO Sample: no, i don't think so ... wait. they're not but ... something is. oh my god., bleu=0.9512
# 2021-06-23 09:45:00,225 INFO Sample: no, i don't think so. right ... they're not with ... all exactly with me all the time, bleu=0.3964
# 2021-06-23 09:45:00,231 INFO Sample: no, i don't think so ... it's pretty in ... #END, bleu=0.3021
# 2021-06-23 09:45:00,239 INFO Sample: no, i don't care. ... is. they're not is ... no all. #END, bleu=0.4571
# 2021-06-23 09:45:09,931 INFO Epoch 8, test BLEU: 0.115
# 2021-06-23 09:45:10,015 INFO Input: #BEG how do you think. #END
# 2021-06-23 09:45:10,016 INFO Refer: i mean did he take you up to his room with him? did you go to a hotel? #END
# 2021-06-23 09:45:10,016 INFO Argmax: i mean did he take you up to his room with him? did you go to a hotel?, bleu=0.9512
# 2021-06-23 09:45:10,026 INFO Sample: i mean did he take you up to his room with him? did you go to a hotel?, bleu=0.9512
# 2021-06-23 09:45:10,036 INFO Sample: i mean did he take you up to his room with him? did you go to a hotel?, bleu=0.9512
# 2021-06-23 09:45:10,046 INFO Sample: i mean did he take you up to his room with him? did you go to a hotel?, bleu=0.9512
# 2021-06-23 09:45:10,055 INFO Sample: i mean did he take you up to his room with me? did you go to me? did, bleu=0.7528
# 2021-06-23 09:45:20,129 INFO Epoch 9, test BLEU: 0.111
# 2021-06-23 09:45:20,209 INFO Input: #BEG oh, no. #END
# 2021-06-23 09:45:20,209 INFO Refer: then what do you do? do you meet someone? #END ~~|~~ what? #END
# 2021-06-23 09:45:20,210 INFO Argmax: what what do you do? do you meet someone? #END, bleu=0.9129
# 2021-06-23 09:45:20,216 INFO Sample: what? do you do? do you meet someone? #END, bleu=0.9129
# 2021-06-23 09:45:20,222 INFO Sample: then? you see me,? you were? #END, bleu=0.2133
# 2021-06-23 09:45:20,228 INFO Sample: what? got you do? do you meet someone? #END, bleu=0.8257
# 2021-06-23 09:45:20,234 INFO Sample: what what do you do? do you meet someone? #END, bleu=0.9129
# 2021-06-23 09:45:30,201 INFO Epoch 10, test BLEU: 0.111
# 2021-06-23 09:45:30,276 INFO Input: #BEG harold! #END
# 2021-06-23 09:45:30,276 INFO Refer: close up shop! #END ~~|~~ what's the chance of getting one of these? #END
# 2021-06-23 09:45:30,277 INFO Argmax: close up shop! getting one of these? #END, bleu=0.9428
# 2021-06-23 09:45:30,282 INFO Sample: close up shop! getting one of these? #END, bleu=0.9428
# 2021-06-23 09:45:30,287 INFO Sample: close up shop! getting one of these? #END, bleu=0.9428
# 2021-06-23 09:45:30,292 INFO Sample: close the chance of getting one of these? #END, bleu=0.9428
# 2021-06-23 09:45:30,295 INFO Sample: close up shop! #END, bleu=1.0000
# 2021-06-23 09:45:40,337 INFO Epoch 11, test BLEU: 0.117
# 2021-06-23 09:45:40,509 INFO Input: #BEG what's wrong? #END
# 2021-06-23 09:45:40,509 INFO Refer: mrs. robinson, you didn't-- i mean you didn't expect-- #END ~~|~~ they go. #END ~~|~~ i think i came. didn't you feel it? #END ~~|~~ be quiet and listen. #END
# 2021-06-23 09:45:40,512 INFO Argmax: they think i came. didn't you feel it? #END, bleu=0.9487
# 2021-06-23 09:45:40,518 INFO Sample: they think i came. didn't you didn't it a? #END, bleu=0.7638
# 2021-06-23 09:45:40,524 INFO Sample: they think i came. didn't you didn't it? #END, bleu=0.8944
# 2021-06-23 09:45:40,533 INFO Sample: be. robinson, you didn't-- i mean-- and didn't--. #END, bleu=0.7001
# 2021-06-23 09:45:40,542 INFO Sample: be. robinson, you didn't---- i mean you didn't expect--- it?, bleu=0.7914
# 2021-06-23 09:45:50,669 INFO Epoch 12, test BLEU: 0.120
# 2021-06-23 09:45:51,039 INFO Input: #BEG well, what do you think? #END
# 2021-06-23 09:45:51,039 INFO Refer: i don't know, bob. what about one of those? #END ~~|~~ i think ... it ... works. #END
# 2021-06-23 09:45:51,042 INFO Argmax: i don't ... it ... works. #END, bleu=0.9258
# 2021-06-23 09:45:51,049 INFO Sample: i don't hate it ... works. about one of those? #END, bleu=0.8321
# 2021-06-23 09:45:51,055 INFO Sample: i don't ... it ... works. about one of those? #END, bleu=0.9129
# 2021-06-23 09:45:51,059 INFO Sample: i don't ... it ... works robinson. #END, bleu=0.7454
# 2021-06-23 09:45:51,064 INFO Sample: i don't have it. works what #END, bleu=0.3536
# 2021-06-23 09:46:01,113 INFO Epoch 13, test BLEU: 0.120
# 2021-06-23 09:46:01,187 INFO Input: #BEG i don't know. #END
# 2021-06-23 09:46:01,188 INFO Refer: it's not the kind of thing you do. #END ~~|~~ but you might. #END ~~|~~ why? what did she tell you? #END ~~|~~ what's this? #END ~~|~~ jesus christ, anthony. did you lose him? #END ~~|~~ nobody was watching? #END ~~|~~ you're as bad as harry ... #END ~~|~~ she is a good looking woman. #END ~~|~~ well the answer is that i don't know either. we haven't done it yet. #END ~~|~~ what was her name? #END
# 2021-06-23 09:46:01,189 INFO Argmax: nobody was a good looking woman. #END, bleu=0.9258
# 2021-06-23 09:46:01,193 INFO Sample: what was her name? #END, bleu=1.0000
# 2021-06-23 09:46:01,201 INFO Sample: jesus christ. is ... i do ... it isn't you we? it off? #END, bleu=0.3092
# 2021-06-23 09:46:01,207 INFO Sample: well you what anthony. did you know? #END, bleu=0.6325
# 2021-06-23 09:46:01,212 INFO Sample: but christ? you think i you you. #END, bleu=0.2789
# 2021-06-23 09:46:11,590 INFO Epoch 14, test BLEU: 0.115
# 2021-06-23 09:46:11,694 INFO Input: #BEG what for? #END
# 2021-06-23 09:46:11,696 INFO Refer: because i don't feel safe until i get the lights on. #END ~~|~~ you know what for. #END
# 2021-06-23 09:46:11,697 INFO Argmax: you i don't feel safe until i get the lights on. #END, bleu=0.9574
# 2021-06-23 09:46:11,705 INFO Sample: you i don't feel safe until i get the lights on. #END, bleu=0.9574
# 2021-06-23 09:46:11,713 INFO Sample: you i don't feel safe until i get the lights on. #END, bleu=0.9574
# 2021-06-23 09:46:11,721 INFO Sample: you i don't feel safe until i get the lights and. #END, bleu=0.8321
# 2021-06-23 09:46:11,728 INFO Sample: you i don't feel safe until i get the lights on. #END, bleu=0.9574
# 2021-06-23 09:46:21,657 INFO Epoch 15, test BLEU: 0.118
# 2021-06-23 09:46:21,917 INFO Input: #BEG i don't believe you. #END
# 2021-06-23 09:46:21,919 INFO Refer: you don't believe me? okay, fine. #END ~~|~~ if i promise you there's really a party with a lot of guys, do you promise you'll go? #END
# 2021-06-23 09:46:21,921 INFO Argmax: if don't believe me? okay, fine. #END, bleu=0.9428
# 2021-06-23 09:46:21,931 INFO Sample: if don't believe me? okay, fine. i want you be of it, the hall. #END, bleu=0.4976
# 2021-06-23 09:46:21,942 INFO Sample: you don't promise you there's really a party with a lot of guys, promise you'll go? #END, bleu=0.8486
# 2021-06-23 09:46:21,948 INFO Sample: if don't believe me? okay, fine. #END, bleu=0.9428
# 2021-06-23 09:46:21,955 INFO Sample: if don't believe me? okay, fine. #END, bleu=0.9428
# 2021-06-23 09:46:31,484 INFO Epoch 16, test BLEU: 0.120
# 2021-06-23 09:46:31,598 INFO Input: #BEG we know what you're up to. #END
# 2021-06-23 09:46:31,599 INFO Refer: probably goin' out to get williams. #END
# 2021-06-23 09:46:31,599 INFO Argmax: probably goin' out to get williams to him. #END, bleu=0.7568
# 2021-06-23 09:46:31,606 INFO Sample: probably goin' out to get williams her of things like it. #END, bleu=0.5883
# 2021-06-23 09:46:31,613 INFO Sample: probably goin' out to get williams to him like it. #END, bleu=0.6355
# 2021-06-23 09:46:31,617 INFO Sample: probably goin' out to get williams. #END, bleu=1.0000
# 2021-06-23 09:46:31,622 INFO Sample: probably goin' out to get williams. #END, bleu=1.0000
# 2021-06-23 09:46:41,477 INFO Epoch 17, test BLEU: 0.116
# 2021-06-23 09:46:41,602 INFO Input: #BEG are you okay? #END
# 2021-06-23 09:46:41,602 INFO Refer: yes. you? #END ~~|~~ yeah. #END ~~|~~ it's just my stupid back. i'll be all right in a minute ... #END
# 2021-06-23 09:46:41,603 INFO Argmax: yeah just my stupid back. i'll be all right in a minute ... #END, bleu=0.9636
# 2021-06-23 09:46:41,610 INFO Sample: yeah just my stupid back. i'll be all right in a minute ... #END, bleu=0.9636
# 2021-06-23 09:46:41,612 INFO Sample: yes. #END, bleu=1.0000
# 2021-06-23 09:46:41,620 INFO Sample: yeah just my stupid back. i'll be all right in a minute ... #END, bleu=0.9636
# 2021-06-23 09:46:41,627 INFO Sample: yeah just the stupid back. back. i'll back in in sister' #END, bleu=0.3381
# 2021-06-23 09:46:51,527 INFO Epoch 18, test BLEU: 0.117
# 2021-06-23 09:46:52,095 INFO Input: #BEG good-bye, darling. #END
# 2021-06-23 09:46:52,096 INFO Refer: good-bye, darling. i love you. i love you, darling. #END ~~|~~ oh, bill, i'll keep it. i'll keep it with me all the time. #END
# 2021-06-23 09:46:52,096 INFO Argmax: oh, darling. i love you. i love you with darling. #END, bleu=0.9258
# 2021-06-23 09:46:52,104 INFO Sample: oh, darling. i love you. i love you in the darling. #END, bleu=0.8660
# 2021-06-23 09:46:52,112 INFO Sample: oh, darling. i'll love you. i'll i'll some you with me? #END, bleu=0.6158
# 2021-06-23 09:46:52,119 INFO Sample: oh, darling. i love you. i love you with me. #END, bleu=0.9258
# 2021-06-23 09:46:52,127 INFO Sample: oh, darling. i love you. i love it in you. #END, bleu=0.8165
# 2021-06-23 09:47:01,686 INFO Epoch 19, test BLEU: 0.113
# 2021-06-23 09:47:01,750 INFO Input: #BEG what are you doing in there? #END
# 2021-06-23 09:47:01,750 INFO Refer: nothing. be right out. #END ~~|~~ i'll be out in a minute. #END
# 2021-06-23 09:47:01,751 INFO Argmax: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:47:01,755 INFO Sample: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:47:01,759 INFO Sample: i'll. be to a man. #END, bleu=0.4629
# 2021-06-23 09:47:01,764 INFO Sample: nothing. be in a minute. #END, bleu=0.9258
# 2021-06-23 09:47:01,768 INFO Sample: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:47:11,807 INFO Epoch 20, test BLEU: 0.110
# 2021-06-23 09:47:11,838 INFO Input: #BEG what's that? only-- you're getting too near. i don't trust anybody. #END
# 2021-06-23 09:47:11,839 INFO Refer: i don't blame you, earl. if i were in your place i wouldn't trust anybody, either. #END
# 2021-06-23 09:47:11,840 INFO Argmax: i don't blame you, earl. if i were in your place i wouldn't trust anybody. #END, bleu=0.8747
# 2021-06-23 09:47:11,849 INFO Sample: i don't blame you, earl. if i were waiting right i love safe. i said that?, bleu=0.5071
# 2021-06-23 09:47:11,859 INFO Sample: i don't blame you, earl. if i were any money. i would think i love you., bleu=0.5071
# 2021-06-23 09:47:11,868 INFO Sample: i don't blame you, earl. if i were to know anybody good. i said it there yet, bleu=0.5278
# 2021-06-23 09:47:11,878 INFO Sample: i don't blame you, earl. right that i love you. i said it to be things three, bleu=0.3780
# 2021-06-23 09:47:21,754 INFO Epoch 21, test BLEU: 0.112
# 2021-06-23 09:47:21,898 INFO Input: #BEG what for? #END
# 2021-06-23 09:47:21,899 INFO Refer: because i don't feel safe until i get the lights on. #END ~~|~~ you know what for. #END
# 2021-06-23 09:47:21,900 INFO Argmax: you i don't feel safe until i get the lights on. #END, bleu=0.9574
# 2021-06-23 09:47:21,906 INFO Sample: you i don't feel safe until i get the lights on. #END, bleu=0.9574
# 2021-06-23 09:47:21,913 INFO Sample: you i don't feel safe until i get the lights on. #END, bleu=0.9574
# 2021-06-23 09:47:21,920 INFO Sample: you i don't feel safe until i get the lights lights in. #END, bleu=0.7703
# 2021-06-23 09:47:21,926 INFO Sample: you i don't feel safe until i get the lights on. #END, bleu=0.9574
# 2021-06-23 09:47:31,851 INFO Epoch 22, test BLEU: 0.114
# 2021-06-23 09:47:32,084 INFO Input: #BEG good. so shall we leave it at that then? #END
# 2021-06-23 09:47:32,085 INFO Refer: we won't leave it, ian. not ever. #END ~~|~~ i dunno. #END
# 2021-06-23 09:47:32,085 INFO Argmax: i dunno leave it, ian. not ever. #END, bleu=0.9487
# 2021-06-23 09:47:32,091 INFO Sample: i dunno leave it, ian. not ever. #END, bleu=0.9487
# 2021-06-23 09:47:32,095 INFO Sample: i dunno. there it. #END, bleu=0.6547
# 2021-06-23 09:47:32,097 INFO Sample: i dunno. #END, bleu=1.0000
# 2021-06-23 09:47:32,103 INFO Sample: i dunno leave it, ian. not ever. #END, bleu=0.9487
# 2021-06-23 09:47:41,826 INFO Epoch 23, test BLEU: 0.118
# 2021-06-23 09:47:41,941 INFO Input: #BEG what do you mean? #END
# 2021-06-23 09:47:41,942 INFO Refer: nothing. #END ~~|~~ the whole business with the art show and the newspaper-- it's absolutely-- #END ~~|~~ feel this. #END
# 2021-06-23 09:47:41,942 INFO Argmax: nothing whole business with the art show and the newspaper-- it's absolutely-- #END, bleu=0.9682
# 2021-06-23 09:47:41,952 INFO Sample: feel the best the business with the art show and the newspaper-- it's absolutely-- #END, bleu=0.8342
# 2021-06-23 09:47:41,960 INFO Sample: nothing whole business with the art show and the newspaper-- it's absolutely-- #END, bleu=0.9682
# 2021-06-23 09:47:41,965 INFO Sample: nothing whole whole with the art stuff. #END, bleu=0.5401
# 2021-06-23 09:47:41,972 INFO Sample: nothing whole business the art show and the newspaper-- it's absolutely-- #END, bleu=0.8745
# 2021-06-23 09:47:51,772 INFO Epoch 24, test BLEU: 0.115
# 2021-06-23 09:47:51,782 INFO Input: #BEG debbie, i'm telling you, i didn't do anything, hardly. #END
# 2021-06-23 09:47:51,783 INFO Refer: the marriage is off. now you can screw around with your friends for the rest of your life. #END
# 2021-06-23 09:47:51,783 INFO Argmax: the marriage is off. now you couldn't to hold for for. #END, bleu=0.3762
# 2021-06-23 09:47:51,790 INFO Sample: you stop that? get hold on there you? for this? #END, bleu=0.0246
# 2021-06-23 09:47:51,796 INFO Sample: that word i've off for for ask some people for you. #END, bleu=0.0968
# 2021-06-23 09:47:51,804 INFO Sample: what word tired you? tell you do i do? just a living? #END, bleu=0.0211
# 2021-06-23 09:47:51,811 INFO Sample: that one him is the first time can i get back for once now. #END, bleu=0.1249
# 2021-06-23 09:48:01,715 INFO Epoch 25, test BLEU: 0.114
# 2021-06-23 09:48:01,893 INFO Input: #BEG how do you think. #END
# 2021-06-23 09:48:01,894 INFO Refer: i mean did he take you up to his room with him? did you go to a hotel? #END
# 2021-06-23 09:48:01,894 INFO Argmax: i mean did he take you up to his room with him? did you? #END, bleu=0.7652
# 2021-06-23 09:48:01,904 INFO Sample: i mean did he take you up to his room with him? i can't you to go. #END, bleu=0.6970
# 2021-06-23 09:48:01,913 INFO Sample: i mean did he take you up to her your with him, mother you go to a hotel?, bleu=0.7038
# 2021-06-23 09:48:01,922 INFO Sample: i mean did he take you up to his room with him? did you for a hotel? #END, bleu=0.8770
# 2021-06-23 09:48:01,932 INFO Sample: i mean did he take you up to his room with him? did you actually give me? #END, bleu=0.7792
# 2021-06-23 09:48:11,684 INFO Epoch 26, test BLEU: 0.114
# 2021-06-23 09:48:11,892 INFO Input: #BEG what's her problem anyway? did she actually tell you you couldn't see me? #END
# 2021-06-23 09:48:11,892 INFO Refer: no, no ... not exactly ... she just doesn't understand how i would know somebody like you ... #END
# 2021-06-23 09:48:11,893 INFO Argmax: no, no ... not exactly ... she she doesn't do i know know somebody is. #END, bleu=0.5217
# 2021-06-23 09:48:11,902 INFO Sample: no, no ... not exactly ... she known gets how do i know know why do you do., bleu=0.4702
# 2021-06-23 09:48:11,912 INFO Sample: no, no ... not exactly ... she dumb what do i know? would you do put anyone out, bleu=0.4702
# 2021-06-23 09:48:11,920 INFO Sample: no, no ... not exactly ... she she doesn't do i know know about anyone. #END, bleu=0.4688
# 2021-06-23 09:48:11,927 INFO Sample: no, no ... not exactly ... she about everything do she do. #END, bleu=0.3925
# 2021-06-23 09:48:22,324 INFO Epoch 27, test BLEU: 0.109
# 2021-06-23 09:48:22,408 INFO Input: #BEG what do you want? #END
# 2021-06-23 09:48:22,408 INFO Refer: i want to speak with you. #END ~~|~~ what do you want? #END ~~|~~ i'm sorry. i was looking for maude. #END
# 2021-06-23 09:48:22,409 INFO Argmax: i do you want? #END, bleu=0.8944
# 2021-06-23 09:48:22,423 INFO Sample: i'm want to do with you. #END, bleu=0.7559
# 2021-06-23 09:48:22,430 INFO Sample: i do you take want you yes. get them of them. #END, bleu=0.2774
# 2021-06-23 09:48:22,438 INFO Sample: what do you i was. for maude. it could any here. #END, bleu=0.5345
# 2021-06-23 09:48:22,442 INFO Sample: i want you the right. i #END, bleu=0.4226
# 2021-06-23 09:48:33,537 INFO Epoch 28, test BLEU: 0.111
# 2021-06-23 09:48:33,631 INFO Input: #BEG i don't. #END
# 2021-06-23 09:48:33,632 INFO Refer: you don't? #END ~~|~~ well that's kind of a bad situation then, isn't it? #END
# 2021-06-23 09:48:33,632 INFO Argmax: you that's kind of a bad situation then, isn't it? #END, bleu=0.9574
# 2021-06-23 09:48:33,639 INFO Sample: you that's kind of a bad situation then, isn't it? #END, bleu=0.9574
# 2021-06-23 09:48:33,645 INFO Sample: you that's kind of a bad situation then, isn't it? #END, bleu=0.9574
# 2021-06-23 09:48:33,652 INFO Sample: you that's kind of a bad situation then, isn't it? #END, bleu=0.9574
# 2021-06-23 09:48:33,658 INFO Sample: you that's kind of a bad situation then, isn't it? #END, bleu=0.9574
# 2021-06-23 09:48:44,916 INFO Epoch 29, test BLEU: 0.112
# 2021-06-23 09:48:44,935 INFO Input: #BEG debbie, i'm telling you, i didn't do anything, hardly. #END
# 2021-06-23 09:48:44,936 INFO Refer: the marriage is off. now you can screw around with your friends for the rest of your life. #END
# 2021-06-23 09:48:44,936 INFO Argmax: the marriage is off. now you couldn't have to hold a man's. #END, bleu=0.3671
# 2021-06-23 09:48:44,944 INFO Sample: beautiful here the money. must just doing to let you in here. #END, bleu=0.1034
# 2021-06-23 09:48:44,953 INFO Sample: the marriage is off. now you why if it is down of the let. they at the like, bleu=0.3780
# 2021-06-23 09:48:44,962 INFO Sample: the marriage is off. now you couldn't wants to hold and i'm in a fight. #END, bleu=0.3841
# 2021-06-23 09:48:44,972 INFO Sample: nothing just hurt him. then, if you have dignan, i'll think i said that i said ago, bleu=0.0218
# 2021-06-23 09:48:55,291 INFO Epoch 30, test BLEU: 0.112
# 2021-06-23 09:48:55,500 INFO Input: #BEG yeah. i suppose i could. but, walter-- #END
# 2021-06-23 09:48:55,500 INFO Refer: he's going to have you the rest of his life, hildy. can't you give me another hour? #END
# 2021-06-23 09:48:55,501 INFO Argmax: he's going to have you the rest of his life. hildy. #END, bleu=0.5126
# 2021-06-23 09:48:55,510 INFO Sample: he's going to have the rest of of yours. life. give. hold any hildy. #END, bleu=0.4130
# 2021-06-23 09:48:55,520 INFO Sample: he's going to have you the rest of his life. hildy! can't let the tickets in. #END, bleu=0.5477
# 2021-06-23 09:48:55,529 INFO Sample: he's going to have the rest of his life. i already. for a hold. #END, bleu=0.4246
# 2021-06-23 09:48:55,536 INFO Sample: he's going to have you the rest of that i hildy. #END, bleu=0.4059
# 2021-06-23 09:49:06,386 INFO Epoch 31, test BLEU: 0.113
# 2021-06-23 09:49:06,397 INFO Input: #BEG tell me something. why didn't you just take the money off luther and split? #END
# 2021-06-23 09:49:06,398 INFO Refer: forget it. i want ganz as bad as you do and i got some other news for you ... #END
# 2021-06-23 09:49:06,398 INFO Argmax: forget it. i want you to know. i would look, i. #END, bleu=0.2671
# 2021-06-23 09:49:06,408 INFO Sample: forget it. i want to know it's yes. i going to anyone yet what's that again. #END, bleu=0.2582
# 2021-06-23 09:49:06,418 INFO Sample: forget it. i want you don't know. i was just afraid up. i am to know anyone, bleu=0.2582
# 2021-06-23 09:49:06,425 INFO Sample: forget it i i want to let it thing never, i'd better? #END, bleu=0.1602
# 2021-06-23 09:49:06,430 INFO Sample: forget it. i want you make bad. #END, bleu=0.1985
# 2021-06-23 09:49:18,228 INFO Epoch 32, test BLEU: 0.113
# 2021-06-23 09:49:18,271 INFO Input: #BEG what was that? #END
# 2021-06-23 09:49:18,272 INFO Refer: i asked her if you were happy to see us. i find it hard to tell with you. #END
# 2021-06-23 09:49:18,272 INFO Argmax: i asked her if you were happy to see us. i find it hard to tell with you., bleu=0.9512
# 2021-06-23 09:49:18,282 INFO Sample: i asked her if you were happy to see us? i find it hard to tell with you., bleu=0.8770
# 2021-06-23 09:49:18,292 INFO Sample: i asked her if you were happy to see us. i find it hard to tell with you., bleu=0.9512
# 2021-06-23 09:49:18,302 INFO Sample: i asked her if you were happy to see us. i find it hard to tell with you., bleu=0.9512
# 2021-06-23 09:49:18,312 INFO Sample: i asked her if you were happy to see us. i find it hard to tell with you., bleu=0.9512
# 2021-06-23 09:49:29,626 INFO Epoch 33, test BLEU: 0.108
# 2021-06-23 09:49:30,001 INFO Input: #BEG what's that? only-- you're getting too near. i don't trust anybody. #END
# 2021-06-23 09:49:30,001 INFO Refer: i don't blame you, earl. if i were in your place i wouldn't trust anybody, either. #END
# 2021-06-23 09:49:30,002 INFO Argmax: i don't blame you. earl. if i were in your place i wouldn't trust anybody in a few, bleu=0.7528
# 2021-06-23 09:49:30,011 INFO Sample: i can't you you when you know that? who? were why leave that hold place. #END, bleu=0.1192
# 2021-06-23 09:49:30,021 INFO Sample: i can't you get out of upset. hildy were hold. come on. i said. #END, bleu=0.1288
# 2021-06-23 09:49:30,030 INFO Sample: i don't blame you. earl. if i were in your place i wouldn't trust anybody i keep., bleu=0.7528
# 2021-06-23 09:49:30,040 INFO Sample: i don't blame you. earl, earl if i ask if i were be anybody i i put back, bleu=0.4141
# 2021-06-23 09:49:40,934 INFO Epoch 34, test BLEU: 0.114
# 2021-06-23 09:49:40,996 INFO Input: #BEG i'm going ... i am ... i'm going to be sick. #END
# 2021-06-23 09:49:40,997 INFO Refer: no you're not. how ... nice one. how dumb do you think i am? #END
# 2021-06-23 09:49:40,997 INFO Argmax: no you're not. how ... nice one. how dumb do you think i know? #END, bleu=0.9129
# 2021-06-23 09:49:41,000 INFO Sample: no, you ... #END, bleu=0.0105
# 2021-06-23 09:49:41,008 INFO Sample: no you're not. how i been nice for life. they deserve right. #END, bleu=0.3418
# 2021-06-23 09:49:41,014 INFO Sample: no you're not, how ... i admit it. #END, bleu=0.2472
# 2021-06-23 09:49:41,022 INFO Sample: no you're not. how ... nice one. how dumb do you know him? #END, bleu=0.7983
# 2021-06-23 09:49:52,549 INFO Epoch 35, test BLEU: 0.111
# 2021-06-23 09:49:52,571 INFO Input: #BEG what are you doing in there? #END
# 2021-06-23 09:49:52,571 INFO Refer: nothing. be right out. #END ~~|~~ i'll be out in a minute. #END
# 2021-06-23 09:49:52,572 INFO Argmax: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:49:52,576 INFO Sample: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:49:52,580 INFO Sample: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:49:52,584 INFO Sample: nothing be out in a. #END, bleu=0.8165
# 2021-06-23 09:49:52,589 INFO Sample: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:50:04,386 INFO Epoch 36, test BLEU: 0.109
# 2021-06-23 09:50:04,477 INFO Input: #BEG debbie, i'm telling you, i didn't do anything, hardly. #END
# 2021-06-23 09:50:04,478 INFO Refer: the marriage is off. now you can screw around with your friends for the rest of your life. #END
# 2021-06-23 09:50:04,478 INFO Argmax: the marriage is off. now you are for a hold person. #END, bleu=0.3762
# 2021-06-23 09:50:04,487 INFO Sample: the marriage is off. now you have to see it" wouldn't i'd know. #END, bleu=0.3804
# 2021-06-23 09:50:04,494 INFO Sample: the marriage is off. now you are for? back down". #END, bleu=0.3870
# 2021-06-23 09:50:04,503 INFO Sample: the marriage is off. now let's hold fifty for a hold days do, hildy. #END, bleu=0.3556
# 2021-06-23 09:50:04,510 INFO Sample: the marriage is off. now you are for hurt him night? #END, bleu=0.3304
# 2021-06-23 09:50:16,881 INFO Epoch 37, test BLEU: 0.111
# 2021-06-23 09:50:17,072 INFO Input: #BEG what are you doing in there? #END
# 2021-06-23 09:50:17,072 INFO Refer: nothing. be right out. #END ~~|~~ i'll be out in a minute. #END
# 2021-06-23 09:50:17,073 INFO Argmax: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:50:17,077 INFO Sample: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:50:17,082 INFO Sample: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:50:17,086 INFO Sample: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:50:17,090 INFO Sample: nothing be out in a minute. #END, bleu=0.9258
# 2021-06-23 09:50:29,306 INFO Epoch 38, test BLEU: 0.114
# 2021-06-23 09:50:29,499 INFO Input: #BEG you look like you could still be in high school. #END
# 2021-06-23 09:50:29,500 INFO Refer: i know, everyone says that. #END
# 2021-06-23 09:50:29,500 INFO Argmax: i know, everyone says that. to know this is. #END, bleu=0.5991
# 2021-06-23 09:50:29,505 INFO Sample: i know, everyone says that. #END, bleu=1.0000
# 2021-06-23 09:50:29,514 INFO Sample: i know, everyone says that. to know had a lot of while, move. #END, bleu=0.4278
# 2021-06-23 09:50:29,523 INFO Sample: i know, everyone says that. this at to be a guy hours. wouldn't sounds. #END, bleu=0.4047
# 2021-06-23 09:50:29,530 INFO Sample: i know, everyone says that. to know about is? #END, bleu=0.5547
# 2021-06-23 09:50:41,766 INFO Epoch 39, test BLEU: 0.117
# 2021-06-23 09:50:41,960 INFO Input: #BEG yeah. i suppose i could. but, walter-- #END
# 2021-06-23 09:50:41,961 INFO Refer: he's going to have you the rest of his life, hildy. can't you give me another hour? #END
# 2021-06-23 09:50:41,962 INFO Argmax: he's going to have you the rest of his name. hildy you give me another a hurt hurt a, bleu=0.6268
# 2021-06-23 09:50:41,971 INFO Sample: he's going to ask you the rest of his life. hildy. can't you give me another hour?, bleu=0.8018
# 2021-06-23 09:50:41,981 INFO Sample: he's going to have you the rest to his a tell your at all right. once a wife?, bleu=0.3780
# 2021-06-23 09:50:41,989 INFO Sample: he's going to have you the rest of his name. hildy you.. #END, bleu=0.4816
# 2021-06-23 09:50:41,998 INFO Sample: he's going to get you the rest of his life. hildy you have a love. #END, bleu=0.4790
# 2021-06-23 09:50:54,440 INFO Epoch 40, test BLEU: 0.112
# 2021-06-23 09:50:54,595 INFO Input: #BEG hello? #END
# 2021-06-23 09:50:54,596 INFO Refer: do you still want to do something tonight? #END ~~|~~ i need to talk to you. #END
# 2021-06-23 09:50:54,596 INFO Argmax: i need still want to do something tonight? #END, bleu=0.9428
# 2021-06-23 09:50:54,602 INFO Sample: i need still talk to do something tonight? #END, bleu=0.8819
# 2021-06-23 09:50:54,607 INFO Sample: i need to want to you something tonight? #END, bleu=0.8819
# 2021-06-23 09:50:54,613 INFO Sample: i need to want to truck something tonight? #END, bleu=0.7746
# 2021-06-23 09:50:54,615 INFO Sample: i need? #END, bleu=0.3004
# 2021-06-23 09:51:06,992 INFO Epoch 41, test BLEU: 0.116
# 2021-06-23 09:51:07,057 INFO Input: #BEG you know how your daddy is. #END
# 2021-06-23 09:51:07,057 INFO Refer: if and when he calls, please don't forget to ask him if he's seen mantan. #END
# 2021-06-23 09:51:07,058 INFO Argmax: if and when he calls, please don't know him to him a movie don't a #END, bleu=0.5017
# 2021-06-23 09:51:07,065 INFO Sample: if and when he calls, fine. be easy a really! #END, bleu=0.3523
# 2021-06-23 09:51:07,075 INFO Sample: if and when he calls, hildy don't know what what are you going to do a movie? #END, bleu=0.3441
# 2021-06-23 09:51:07,079 INFO Sample: if and when he calls- #END, bleu=0.1570
# 2021-06-23 09:51:07,087 INFO Sample: if and when he calls to keep a coming out to do you met a movie? #END, bleu=0.3025
# 2021-06-23 09:51:19,696 INFO Epoch 42, test BLEU: 0.108
# 2021-06-23 09:51:19,758 INFO Input: #BEG it'll bring us together again, hildy-- just the way we used to be. #END
# 2021-06-23 09:51:19,758 INFO Refer: that's what i'm afraid of." any time-- any place-- anywhere!" #END
# 2021-06-23 09:51:19,759 INFO Argmax: that's what i'm afraid of." any time-- any place-- anywhere! #END, bleu=0.9177
# 2021-06-23 09:51:19,768 INFO Sample: that's what i'm afraid of." any time-- any place-- anywhere! #END, bleu=0.9177
# 2021-06-23 09:51:19,776 INFO Sample: that's what i'm afraid of." any time-- any place-- anywhere! #END, bleu=0.9177
# 2021-06-23 09:51:19,785 INFO Sample: that's what i'm afraid of." any time-- any place-- anywhere! #END, bleu=0.9177
# 2021-06-23 09:51:19,795 INFO Sample: that's what i'm afraid of." any time-- any place-- anywhere!" #END, bleu=1.0000
# 2021-06-23 09:51:33,046 INFO Epoch 43, test BLEU: 0.107
# 2021-06-23 09:51:33,170 INFO Input: #BEG what are you trying to say? #END
# 2021-06-23 09:51:33,171 INFO Refer: it's just that i feel like it's maybe not a good idea for us to keep going out. #END
# 2021-06-23 09:51:33,171 INFO Argmax: it's just that i feel like it's maybe not a good idea for us. keep going out. #END, bleu=0.9220
# 2021-06-23 09:51:33,179 INFO Sample: it's just that maybe i like. maybe not gonna to bring with us. #END, bleu=0.3335
# 2021-06-23 09:51:33,187 INFO Sample: it's just that i feel like it's maybe not a good idea for us. #END, bleu=0.7524
# 2021-06-23 09:51:33,197 INFO Sample: it's just that i feel like it's maybe not a good idea for us to keep going out. #END, bleu=1.0000
# 2021-06-23 09:51:33,205 INFO Sample: it's just that i feel like it's maybe not a good idea for us. #END, bleu=0.7524
# 2021-06-23 09:51:46,034 INFO Epoch 44, test BLEU: 0.111
# 2021-06-23 09:51:46,177 INFO Input: #BEG i guess. you're lucky you don't have any old people around here. #END
# 2021-06-23 09:51:46,178 INFO Refer: she was about to get married again. she locked me out of the bedroom last night. #END
# 2021-06-23 09:51:46,179 INFO Argmax: she was about to get married again. she locked me out of a bedroom like things. #END, bleu=0.7799
# 2021-06-23 09:51:46,188 INFO Sample: she was about to get married again. she locked me out of the bedroom like. #END, bleu=0.8635
# 2021-06-23 09:51:46,192 INFO Sample: she was it to married. #END, bleu=0.0963
# 2021-06-23 09:51:46,200 INFO Sample: she was it to lie. if i see you to just a want. #END, bleu=0.1854
# 2021-06-23 09:51:46,208 INFO Sample: she was about to get married again. she locked me out of course. #END, bleu=0.7473
# 2021-06-23 09:51:59,261 INFO Epoch 45, test BLEU: 0.119
# 2021-06-23 09:51:59,278 INFO Input: #BEG i'm going ... i am ... i'm going to be sick. #END
# 2021-06-23 09:51:59,278 INFO Refer: no you're not. how ... nice one. how dumb do you think i am? #END
# 2021-06-23 09:51:59,279 INFO Argmax: no you're not. how ... nice one. how dumb do you know him? #END, bleu=0.7983
# 2021-06-23 09:51:59,288 INFO Sample: no you're not. how ... if i had know ... i wouldn't. like here. #END, bleu=0.3835
# 2021-06-23 09:51:59,297 INFO Sample: no you're not. how we've nice know. how dumb. you just had some name. #END, bleu=0.4393
# 2021-06-23 09:51:59,303 INFO Sample: no you're not. how how i like. #END, bleu=0.2842
# 2021-06-23 09:51:59,311 INFO Sample: no you're not. how ... nice one. how dumb you do you do too. #END, bleu=0.7094
# 2021-06-23 09:52:13,007 INFO Epoch 46, test BLEU: 0.116
# 2021-06-23 09:52:13,014 INFO Input: #BEG i have a lunch date. i just want-- #END
# 2021-06-23 09:52:13,015 INFO Refer: you can break it, can't you? #END
# 2021-06-23 09:52:13,015 INFO Argmax: you can break it, you don't know. #END, bleu=0.5578
# 2021-06-23 09:52:13,021 INFO Sample: go ahead- don't you wanted to know about cake. #END, bleu=0.0389
# 2021-06-23 09:52:13,026 INFO Sample: you can break it, you don't #END, bleu=0.6240
# 2021-06-23 09:52:13,031 INFO Sample: you can break it, you idiot this! #END, bleu=0.5578
# 2021-06-23 09:52:13,035 INFO Sample: you can break it, earl you #END, bleu=0.6240
# 2021-06-23 09:52:27,434 INFO Epoch 47, test BLEU: 0.116
# 2021-06-23 09:52:27,481 INFO Input: #BEG good-bye, darling. #END
# 2021-06-23 09:52:27,482 INFO Refer: good-bye, darling. i love you. i love you, darling. #END ~~|~~ oh, bill, i'll keep it. i'll keep it with me all the time. #END
# 2021-06-23 09:52:27,482 INFO Argmax: oh, darling. i love you. i love you with darling. #END, bleu=0.9258
# 2021-06-23 09:52:27,490 INFO Sample: oh, darling. i love you. i love it, darling. #END, bleu=0.9258
# 2021-06-23 09:52:27,497 INFO Sample: oh, darling. i love you. i love you with me. #END, bleu=0.9258
# 2021-06-23 09:52:27,504 INFO Sample: oh, clock. i love you. i love you hold. #END, bleu=0.7172
# 2021-06-23 09:52:27,512 INFO Sample: oh, darling. i love you. i love you with darling. #END, bleu=0.9258
# 2021-06-23 09:52:40,692 INFO Epoch 48, test BLEU: 0.115
# 2021-06-23 09:52:40,769 INFO Input: #BEG you told me that part already. #END
# 2021-06-23 09:52:40,770 INFO Refer: hell, i've just been going over the whole thing in my head and- #END
# 2021-06-23 09:52:40,771 INFO Argmax: hell, i've just been going over the whole thing in the head. #END, bleu=0.7361
# 2021-06-23 09:52:40,778 INFO Sample: hell, i've just been going over the whole thing in the head. #END, bleu=0.7361
# 2021-06-23 09:52:40,786 INFO Sample: hell, i've just been going over the whole thing in my head and- #END, bleu=1.0000
# 2021-06-23 09:52:40,794 INFO Sample: hell, i've just been going over the whole thing in the head. #END, bleu=0.7361
# 2021-06-23 09:52:40,799 INFO Sample: hell, i've just been going to hear thing. #END, bleu=0.3828
# 2021-06-23 09:52:54,970 INFO Epoch 49, test BLEU: 0.111
# 2021-06-23 09:52:54,980 INFO Input: #BEG who we are. don't you think they're going to be pissed? #END
# 2021-06-23 09:52:54,980 INFO Refer: are you kidding? i'm not going to tell them. #END
# 2021-06-23 09:52:54,980 INFO Argmax: i have to have. i want to be the truth. #END, bleu=0.1387
# 2021-06-23 09:52:54,986 INFO Sample: are you kidding? i'm not going to them. #END, bleu=0.8662
# 2021-06-23 09:52:54,988 INFO Sample: are you. #END, bleu=0.1105
# 2021-06-23 09:52:55,002 INFO Sample: i have to talk to use this. i to see here. #END, bleu=0.1284
# 2021-06-23 09:52:55,011 INFO Sample: i have to have. i see where. we them class to a real like. #END, bleu=0.1143
# 2021-06-23 09:53:09,342 INFO Epoch 50, test BLEU: 0.111
# 2021-06-23 09:53:09,374 INFO Input: #BEG well, a guy can win when hildy ain't around. #END
# 2021-06-23 09:53:09,374 INFO Refer: who's this guy she's gonna marry? #END
# 2021-06-23 09:53:09,375 INFO Argmax: who's this guy she's gonna marry ... ... she doesn't. #END, bleu=0.5149
# 2021-06-23 09:53:09,382 INFO Sample: who's this guy she's gonna marry .... she are to know. #END, bleu=0.4385
# 2021-06-23 09:53:09,388 INFO Sample: who's this guy she's gonna marry? ... marry to be. #END, bleu=0.5547
# 2021-06-23 09:53:09,395 INFO Sample: who's this guy she's gonna marry ... why are a change. #END, bleu=0.4737
# 2021-06-23 09:53:09,401 INFO Sample: who's this guy she's gonna marry ... ... you'll see .... #END, bleu=0.4737
# 2021-06-23 09:53:23,836 INFO Epoch 51, test BLEU: 0.110
# 2021-06-23 09:53:23,864 INFO Input: #BEG are they behind us? #END
# 2021-06-23 09:53:23,865 INFO Refer: no, i don't think so ... wait. they're not but ... something is. oh my god. #END
# 2021-06-23 09:53:23,865 INFO Argmax: no, i don't think so ... wait. they're not but ... something is. oh my god., bleu=0.9512
# 2021-06-23 09:53:23,875 INFO Sample: no, i don't think so wait. they're not but ... something is. ... this is my ..., bleu=0.7254
# 2021-06-23 09:53:23,884 INFO Sample: no, i don't think so ... wait. they're not but ... something is something ... how something-, bleu=0.7071
# 2021-06-23 09:53:23,893 INFO Sample: no, i don't think so. wait. they're not but ... something is. oh my god., bleu=0.8770
# 2021-06-23 09:53:23,903 INFO Sample: no, i don't think so ... wait. they're not but ... something is ... oh my god ..., bleu=0.8281
# 2021-06-23 09:53:38,070 INFO Epoch 52, test BLEU: 0.114
# 2021-06-23 09:53:38,102 INFO Input: #BEG where are you, pete? #END
# 2021-06-23 09:53:38,102 INFO Refer: third floor. get down here, #END
# 2021-06-23 09:53:38,102 INFO Argmax: third floor. get down here. #END, bleu=0.7906
# 2021-06-23 09:53:38,107 INFO Sample: third floor. get down here. #END, bleu=0.7906
# 2021-06-23 09:53:38,111 INFO Sample: third floor. get her here. #END, bleu=0.5669
# 2021-06-23 09:53:38,115 INFO Sample: third floor. get down here. #END, bleu=0.7906
# 2021-06-23 09:53:38,118 INFO Sample: third is. #END, bleu=0.0582
# 2021-06-23 09:53:52,750 INFO Epoch 53, test BLEU: 0.114
# 2021-06-23 09:53:52,814 INFO Input: #BEG do you think things will be a lot different on mercury, dad? #END
# 2021-06-23 09:53:52,814 INFO Refer: it's going to be terrific. a whole new world, new kids to play with. #END
# 2021-06-23 09:53:52,815 INFO Argmax: it's going to be terrific. a whole new world, new kids to play.. #END, bleu=0.9129
# 2021-06-23 09:53:52,823 INFO Sample: it's going to be terrific. a whole new world, new kids to play here. #END, bleu=0.9129
# 2021-06-23 09:53:52,832 INFO Sample: it's going to be terrific. a whole new world, new. in the right. #END, bleu=0.7410
# 2021-06-23 09:53:52,841 INFO Sample: it's going to be terrific. a whole new world, new kids in a second. #END, bleu=0.7983
# 2021-06-23 09:53:52,848 INFO Sample: it's going to be terrific. a whole new world, new kids. #END, bleu=0.7889
# 2021-06-23 09:54:07,309 INFO Epoch 54, test BLEU: 0.112
# 2021-06-23 09:54:07,343 INFO Input: #BEG no. it's too soon. #END
# 2021-06-23 09:54:07,344 INFO Refer: it's never too soon! girls decide how far to let you go in the first five minutes. #END
# 2021-06-23 09:54:07,344 INFO Argmax: it's never too soon! girls decide how far to let you go to love me. #END, bleu=0.7143
# 2021-06-23 09:54:07,352 INFO Sample: it's never too soon! girls decide how far to calm know how you wanted. #END, bleu=0.5795
# 2021-06-23 09:54:07,360 INFO Sample: it's never too soon! girls decide how far to know you wanted to go. #END, bleu=0.6014
# 2021-06-23 09:54:07,369 INFO Sample: it's never too soon! girls decide how far to let you go have again, bruce. #END, bleu=0.7164
# 2021-06-23 09:54:07,379 INFO Sample: it's never too soon! girls decide how far why doesn't if upstairs! you don't have to. #END, bleu=0.5549
# 2021-06-23 09:54:21,440 INFO Epoch 55, test BLEU: 0.115
# 2021-06-23 09:54:21,449 INFO Input: #BEG you don't have to worry about that with us, sir. #END
# 2021-06-23 09:54:21,449 INFO Refer: right. we'll believe anything. #END
# 2021-06-23 09:54:21,450 INFO Argmax: right. we'll believe you. #END, bleu=0.7559
# 2021-06-23 09:54:21,456 INFO Sample: right. we'll, anything. i want to be. #END, bleu=0.4264
# 2021-06-23 09:54:21,462 INFO Sample: hey, can you-- what you understand any and. #END, bleu=0.1132
# 2021-06-23 09:54:21,467 INFO Sample: thank. did you don't want to. #END, bleu=0.2041
# 2021-06-23 09:54:21,470 INFO Sample: yes, i i want. #END, bleu=0.2182
# 2021-06-23 09:54:36,089 INFO Epoch 56, test BLEU: 0.117
# 2021-06-23 09:54:36,230 INFO Input: #BEG no ... they said she was here ... #END
# 2021-06-23 09:54:36,231 INFO Refer: what the fuck is she doing?! she was supposed to be here three hours ago! #END
# 2021-06-23 09:54:36,231 INFO Argmax: what the fuck is she?? #END, bleu=0.1788
# 2021-06-23 09:54:36,235 INFO Sample: what the fuck is she doing? #END, bleu=0.2341
# 2021-06-23 09:54:36,239 INFO Sample: what the do, hold? #END, bleu=0.0556
# 2021-06-23 09:54:36,243 INFO Sample: what the fuck is she?? #END, bleu=0.1788
# ...
# 2021-06-23 10:18:41,191 INFO Refer: thanks. #END
# 2021-06-23 10:18:41,192 INFO Argmax: fine. #END, bleu=0.5774
# 2021-06-23 10:18:41,194 INFO Sample: fine. #END, bleu=0.5774
# 2021-06-23 10:18:41,196 INFO Sample: fine. #END, bleu=0.5774
# 2021-06-23 10:18:41,198 INFO Sample: fine. #END, bleu=0.5774
# 2021-06-23 10:18:41,200 INFO Sample: fine. #END, bleu=0.5774
# 2021-06-23 10:18:57,250 INFO Epoch 151, test BLEU: 0.111
# 2021-06-23 10:18:57,299 INFO Input: #BEG look ... i ... i'm sorry. i don't want to be any part of this. #END
# 2021-06-23 10:18:57,300 INFO Refer: suit yourself. there are plenty of others who will. #END
# 2021-06-23 10:18:57,300 INFO Argmax: suit yourself. there are plenty of others who? #END, bleu=0.7787
# 2021-06-23 10:18:57,303 INFO Sample: suit yourself. #END, bleu=0.1353
# 2021-06-23 10:18:57,310 INFO Sample: suit yourself. put it for a week! i have her #END, bleu=0.2265
# 2021-06-23 10:18:57,312 INFO Sample: suit yourself. #END, bleu=0.1353
# 2021-06-23 10:18:57,315 INFO Sample: suit yourself. #END, bleu=0.1353
# 2021-06-23 10:19:12,742 INFO Epoch 152, test BLEU: 0.115
# 2021-06-23 10:19:12,842 INFO Input: #BEG come on! #END
# 2021-06-23 10:19:12,843 INFO Refer: i don't want to fight you, dignan. #END ~~|~~ he's dead. #END
# 2021-06-23 10:19:12,843 INFO Argmax: he's don't want to fight you, dignan. #END, bleu=0.9428
# 2021-06-23 10:19:12,849 INFO Sample: he's don't want to fight you, dignan. #END, bleu=0.9428
# 2021-06-23 10:19:12,854 INFO Sample: he's don't want to fight you, dignan. #END, bleu=0.9428
# 2021-06-23 10:19:12,860 INFO Sample: he's don't want to fight you, dignan. #END, bleu=0.9428
# 2021-06-23 10:19:12,865 INFO Sample: he's don't want to fight you, dignan. #END, bleu=0.9428
# 2021-06-23 10:19:27,866 INFO Epoch 153, test BLEU: 0.120
# 2021-06-23 10:19:27,885 INFO Input: #BEG of course he does. but he might get the wrong idea. anyone might. #END
# 2021-06-23 10:19:27,885 INFO Refer: i don't see why. i'm twice as old as you are. how could anyone think-- #END
# 2021-06-23 10:19:27,885 INFO Argmax: i don't see why. i'm twice as old as you are. how could anyone-- #END, bleu=0.9220
# 2021-06-23 10:19:27,895 INFO Sample: i don't see why. i'm twice as old as you know. how could anyone think-- #END, bleu=0.9220
# 2021-06-23 10:19:27,902 INFO Sample: i don't even think to mother mother you they keep you when what. #END, bleu=0.1211
# 2021-06-23 10:19:27,912 INFO Sample: i don't see why. i'm twice as old as you are. how could anyone got-- #END, bleu=0.9220
# 2021-06-23 10:19:27,921 INFO Sample: i don't see why. i'm twice as old as you are. how could anyone know-- #END, bleu=0.9220
# 2021-06-23 10:19:42,369 INFO Epoch 154, test BLEU: 0.121
# 2021-06-23 10:19:42,410 INFO Input: #BEG what? you're kidding me ... #END
# 2021-06-23 10:19:42,410 INFO Refer: yeah, so i better go-- it's not really the best time to talk ... #END
# 2021-06-23 10:19:42,410 INFO Argmax: yeah, so i better go-- i mean in we is her. no. #END, bleu=0.4537
# 2021-06-23 10:19:42,419 INFO Sample: yeah, so i better go-- no. not really us the end. #END, bleu=0.5602
# 2021-06-23 10:19:42,427 INFO Sample: yeah, so i better go-- i mean you didn't too this is no. #END, bleu=0.4537
# 2021-06-23 10:19:42,435 INFO Sample: yeah, so i better go is-- you really wanna you anyone me? #END, bleu=0.4428
# 2021-06-23 10:19:42,441 INFO Sample: yeah, so i better go go- is very. #END, bleu=0.3658
# 2021-06-23 10:19:56,007 INFO Epoch 155, test BLEU: 0.116
# 2021-06-23 10:19:56,026 INFO Input: #BEG may i please see the storage facility? #END
# 2021-06-23 10:19:56,027 INFO Refer: why do you want to see it? #END
# 2021-06-23 10:19:56,027 INFO Argmax: why do you want to do it? #END, bleu=0.8165
# 2021-06-23 10:19:56,032 INFO Sample: why do you want to see it? #END, bleu=1.0000
# 2021-06-23 10:19:56,036 INFO Sample: why do you want to do it? #END, bleu=0.8165
# 2021-06-23 10:19:56,041 INFO Sample: why do you want to see it? #END, bleu=1.0000
# 2021-06-23 10:19:56,046 INFO Sample: afraid do you want to do it? #END, bleu=0.6972
# 2021-06-23 10:20:10,056 INFO Epoch 156, test BLEU: 0.112
# 2021-06-23 10:20:10,082 INFO Input: #BEG how are you, benjamin? #END
# 2021-06-23 10:20:10,082 INFO Refer: fine, thank you. the bathroom is down at the end of the hall. #END
# 2021-06-23 10:20:10,082 INFO Argmax: fine, thank you. the bathroom is down and the the of the hall. #END, bleu=0.8135
# 2021-06-23 10:20:10,090 INFO Sample: fine, but i can't? this, hardly, of your here. #END, bleu=0.1910
# 2021-06-23 10:20:10,098 INFO Sample: fine, thank you. the world is a mind with anyone the good. #END, bleu=0.4697
# 2021-06-23 10:20:10,105 INFO Sample: fine, thank you. the bathroom is down. the hall. #END, bleu=0.7154
# 2021-06-23 10:20:10,112 INFO Sample: fine, thank you. the bathroom is down and the good? #END, bleu=0.5612
# 2021-06-23 10:20:23,611 INFO Epoch 157, test BLEU: 0.108
# 2021-06-23 10:20:23,646 INFO Input: #BEG how do you think. #END
# 2021-06-23 10:20:23,646 INFO Refer: i mean did he take you up to his room with him? did you go to a hotel? #END
# 2021-06-23 10:20:23,650 INFO Argmax: i mean did he take you up to his room with him? did you go to a hotel?, bleu=0.9512
# 2021-06-23 10:20:23,657 INFO Sample: i mean did mind if you could a movie? #END, bleu=0.1760
# 2021-06-23 10:20:23,668 INFO Sample: i mean did he take you up to his room with him? did you go to a hotel?, bleu=0.9512
# 2021-06-23 10:20:23,681 INFO Sample: i mean did he take you up to his room with him? did you go to a hotel?, bleu=0.9512
# 2021-06-23 10:20:23,692 INFO Sample: i mean did he take you up to his room with him? did you go to a hotel?, bleu=0.9512
# 2021-06-23 10:20:37,240 INFO Epoch 158, test BLEU: 0.110
# 2021-06-23 10:20:37,336 INFO Input: #BEG did you see what i meant about the window? #END
# 2021-06-23 10:20:37,338 INFO Refer: kind of. except we've already got the keys. #END
# 2021-06-23 10:20:37,340 INFO Argmax: kind of. except we've already got a keys. #END, bleu=0.8528
# 2021-06-23 10:20:37,347 INFO Sample: kind of. except we've already a keys. #END, bleu=0.7570
# 2021-06-23 10:20:37,354 INFO Sample: kind of. except we've already got a keys. #END, bleu=0.8528
# 2021-06-23 10:20:37,362 INFO Sample: kind of. except we've already got a the keys. #END, bleu=0.8660
# 2021-06-23 10:20:37,369 INFO Sample: kind of. except we've already got a keys. #END, bleu=0.8528
# 2021-06-23 10:20:50,500 INFO Epoch 159, test BLEU: 0.105
# 2021-06-23 10:20:50,567 INFO Input: #BEG yeah. i'm not the one who's in love with the guy. #END
# 2021-06-23 10:20:50,569 INFO Refer: what?! now hold on! wait one damn minute! #END
# 2021-06-23 10:20:50,571 INFO Argmax: just go with him! bruce, ted! #END, bleu=0.1353
# 2021-06-23 10:20:50,577 INFO Sample: you're gonna go! by!! #END, bleu=0.1431
# 2021-06-23 10:20:50,582 INFO Sample: just a light!! #END, bleu=0.0985
# 2021-06-23 10:20:50,592 INFO Sample: i go!! he say!! was coming! to hold that in here? #END, bleu=0.0443
# 2021-06-23 10:20:50,600 INFO Sample: i have a chance!! damn that! i that trust! #END, bleu=0.1657
# 2021-06-23 10:21:03,884 INFO Epoch 160, test BLEU: 0.108
# 2021-06-23 10:21:04,207 INFO Input: #BEG what ... you mean" got into bed with" them? #END
# 2021-06-23 10:21:04,208 INFO Refer: no, of course not, silly-- i mean felt like this about them? #END
# 2021-06-23 10:21:04,208 INFO Argmax: no, of course not, silly-- i mean felt like this about us about. #END, bleu=0.8093
# 2021-06-23 10:21:04,217 INFO Sample: no, of course not, silly-- i mean you're i like anyone like #END, bleu=0.6518
# 2021-06-23 10:21:04,227 INFO Sample: no, of course not, silly-- i mean felt like this about about about other of them, bleu=0.7678
# 2021-06-23 10:21:04,236 INFO Sample: no, of, shut, silly-- i mean felt like this about her bedroom? #END, bleu=0.7255
# 2021-06-23 10:21:04,245 INFO Sample: no, of course not, silly-- i mean felt like this about them? #END, bleu=1.0000
# 2021-06-23 10:21:17,744 INFO Epoch 161, test BLEU: 0.113
# 2021-06-23 10:21:17,824 INFO Input: #BEG you slept too near where you got in? #END
# 2021-06-23 10:21:17,825 INFO Refer: i slept too near where i fell out. #END
# 2021-06-23 10:21:17,825 INFO Argmax: i slept too near where i fell. #END, bleu=0.8370
# 2021-06-23 10:21:17,831 INFO Sample: i slept too near where i fell some.. #END, bleu=0.7568
# 2021-06-23 10:21:17,836 INFO Sample: i slept too near where i fell.. #END, bleu=0.8367
# 2021-06-23 10:21:17,845 INFO Sample: i slept slept woman he as ted, is. right to hold a minute. #END, bleu=0.1715
# 2021-06-23 10:21:17,849 INFO Sample: i slept too near to but you. #END, bleu=0.5166
# 2021-06-23 10:21:31,338 INFO Epoch 162, test BLEU: 0.109
# 2021-06-23 10:21:31,381 INFO Input: #BEG but-- #END
# 2021-06-23 10:21:31,382 INFO Refer: believe me, bruce, i know what i'm doing. he'd get you in a crap game-- #END
# 2021-06-23 10:21:31,383 INFO Argmax: believe me, bruce, i know what i'm doing. he'd get you in a crap game--, bleu=0.9512
# 2021-06-23 10:21:31,393 INFO Sample: believe me, bruce, i know what i'm doing. he'd get in a crap game-- #END, bleu=0.9259
# 2021-06-23 10:21:31,402 INFO Sample: believe me, bruce, i know what i'm doing. he'd get you in a crap game--, bleu=0.9512
# 2021-06-23 10:21:31,412 INFO Sample: believe me, bruce, i know what i'm doing. he'd get you in a crap game--, bleu=0.9512
# 2021-06-23 10:21:31,422 INFO Sample: believe me, bruce, i know what i'm doing. he'd get you in a crap game--, bleu=0.9512
# 2021-06-23 10:21:44,485 INFO Epoch 163, test BLEU: 0.103
# 2021-06-23 10:21:44,516 INFO Input: #BEG you've got to respect that. #END
# 2021-06-23 10:21:44,517 INFO Refer: i have to say that i'm not there yet. #END
# 2021-06-23 10:21:44,517 INFO Argmax: just have to come in the way. #END, bleu=0.2669
# 2021-06-23 10:21:44,520 INFO Sample: maybe a minute. #END, bleu=0.0952
# 2021-06-23 10:21:44,524 INFO Sample: just a minute. #END, bleu=0.0952
# 2021-06-23 10:21:44,527 INFO Sample: have a minute. what? #END, bleu=0.0477
# 2021-06-23 10:21:44,530 INFO Sample: just have a #END, bleu=0.0224
# 2021-06-23 10:21:57,406 INFO Epoch 164, test BLEU: 0.103
# 2021-06-23 10:21:57,414 INFO Input: #BEG that's always a good idea! would you like some money? i have a great deal of it. #END
# 2021-06-23 10:21:57,414 INFO Refer: no. i don't need money anymore-- i see that now. #END
# 2021-06-23 10:21:57,415 INFO Argmax: no. i don't need money anymore-- #END, bleu=0.5718
# 2021-06-23 10:21:57,420 INFO Sample: no. i don't need money anymore-- #END, bleu=0.5718
# 2021-06-23 10:21:57,425 INFO Sample: no. i don't need money anymore-- #END, bleu=0.5718
# 2021-06-23 10:21:57,430 INFO Sample: no. i don't need money anymore-- #END, bleu=0.5718
# 2021-06-23 10:21:57,436 INFO Sample: no. i mean need-- i think- #END, bleu=0.3749
# 2021-06-23 10:22:09,366 INFO Epoch 165, test BLEU: 0.101
# 2021-06-23 10:22:09,391 INFO Input: #BEG look, i'm kind of in a hurry. #END
# 2021-06-23 10:22:09,391 INFO Refer: i'm in a hurry too. i just thought i could say hi to you. #END
# 2021-06-23 10:22:09,391 INFO Argmax: i'm in a hurry too. i just thought i could say hi to. #END, bleu=0.9076
# 2021-06-23 10:22:09,400 INFO Sample: i'm in a hurry too. i just thought i could say. just you. #END, bleu=0.8467
# 2021-06-23 10:22:09,408 INFO Sample: i'm in a hurry too. i just thought i could say hi to you. #END, bleu=1.0000
# 2021-06-23 10:22:09,416 INFO Sample: i'm in a hurry too. i just thought i thought. things day back. #END, bleu=0.6642
# 2021-06-23 10:22:09,425 INFO Sample: i'm in a hurry too. i just thought i leave say to get your to. #END, bleu=0.6764
# 2021-06-23 10:22:21,664 INFO Epoch 166, test BLEU: 0.105
# 2021-06-23 10:22:21,942 INFO Input: #BEG i can hear you, but where the fuck are you, man? #END
# 2021-06-23 10:22:21,943 INFO Refer: what i been wondering is where's he been. #END
# 2021-06-23 10:22:21,943 INFO Argmax: what i been wondering is where's bad. #END, bleu=0.7306
# 2021-06-23 10:22:21,949 INFO Sample: what i been wondering is end are this is. #END, bleu=0.5641
# 2021-06-23 10:22:21,953 INFO Sample: that's a kind of been to for. #END, bleu=0.1827
# 2021-06-23 10:22:21,959 INFO Sample: what i been wondering is while he might for. #END, bleu=0.6030
# 2021-06-23 10:22:21,966 INFO Sample: what i been wondering is a bad and for how you mean. #END, bleu=0.4385
# 2021-06-23 10:22:33,578 INFO Epoch 167, test BLEU: 0.108
# 2021-06-23 10:22:33,594 INFO Input: #BEG debbie, i'm telling you, i didn't do anything, hardly. #END
# 2021-06-23 10:22:33,595 INFO Refer: the marriage is off. now you can screw around with your friends for the rest of your life. #END
# 2021-06-23 10:22:33,595 INFO Argmax: the marriage is off. now you can screw around with your friends for the rest of your life., bleu=0.9512
# 2021-06-23 10:22:33,605 INFO Sample: the marriage is off. now you can have around for the rest here your rest of your life., bleu=0.7254
# 2021-06-23 10:22:33,614 INFO Sample: the marriage is off. now you can stop for a friends for the rest of your life. #END, bleu=0.7792
# 2021-06-23 10:22:33,624 INFO Sample: the marriage is off. now you all right around for another friends here now you hold the before., bleu=0.4141
# 2021-06-23 10:22:33,634 INFO Sample: the marriage is off. now you can screw around with your friends for the rest of your life., bleu=0.9512
# 2021-06-23 10:22:45,582 INFO Epoch 168, test BLEU: 0.111
# 2021-06-23 10:22:45,607 INFO Input: #BEG i don't believe you. #END
# 2021-06-23 10:22:45,607 INFO Refer: you don't believe me? okay, fine. #END ~~|~~ if i promise you there's really a party with a lot of guys, do you promise you'll go? #END
# 2021-06-23 10:22:45,608 INFO Argmax: if don't believe me? okay, fine. #END, bleu=0.9428
# 2021-06-23 10:22:45,613 INFO Sample: if don't believe me? okay, fine. #END, bleu=0.9428
# 2021-06-23 10:22:45,618 INFO Sample: if don't believe me? okay, fine. #END, bleu=0.9428
# 2021-06-23 10:22:45,623 INFO Sample: if don't believe me? okay, fine. #END, bleu=0.9428
# 2021-06-23 10:22:45,628 INFO Sample: if don't believe me? okay, fine. #END, bleu=0.9428
# 2021-06-23 10:22:57,547 INFO Epoch 169, test BLEU: 0.116
# 2021-06-23 10:22:57,844 INFO Input: #BEG what's that? only-- you're getting too near. i don't trust anybody. #END
# 2021-06-23 10:22:57,844 INFO Refer: i don't blame you, earl. if i were in your place i wouldn't trust anybody, either. #END
# 2021-06-23 10:22:57,844 INFO Argmax: i don't blame you, earl. if i were in your place i wouldn't trust anybody, either., bleu=0.9512
# 2021-06-23 10:22:57,854 INFO Sample: i don't blame you, earl. if i were in your place i wouldn't trust anybody, either., bleu=0.9512
# 2021-06-23 10:22:57,863 INFO Sample: i don't blame you, earl. if i were in your place i wouldn't trust anybody, either., bleu=0.9512
# 2021-06-23 10:22:57,873 INFO Sample: i don't blame you, earl. if i were in your place i wouldn't trust anybody, either., bleu=0.9512
# 2021-06-23 10:22:57,882 INFO Sample: i don't blame you, earl. if i were in your bank i wouldn't trust anybody, like., bleu=0.8018
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-ce5c023ae217> in <module>
#     157
#     158         loss_v = loss_policy_v
# --> 159         loss_v.backward()
#     160         optimiser.step()
#     161
#
# /mnt/local/anaconda3/envs/huggingface-env/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# /mnt/local/anaconda3/envs/huggingface-env/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
# EVALUATION
import argparse
import logging

import torch

log = logging.getLogger("data_test")

logging.basicConfig(format="%(asctime)-15s %(levelname)s %(message)s", level=logging.INFO)
data_genre = "comedy"
cuda_available = True 
name_of_the_run = 'comedy_conversations'
model_path = "data/comedy_conversations/epoch_160_0.991_0.108.dat"
device = torch.device("cuda" if cuda_available else "cpu")


phrase_pairs, emb_dict = load_data(data_genre)
log.info("Obtained %d phrase pairs with %d uniq words", len(phrase_pairs), len(emb_dict))
train_data = encode_phrase_pairs(phrase_pairs, emb_dict)
train_data = group_train_data(train_data)
rev_emb_dict = {idx: word for word, idx in emb_dict.items()}

net = PhraseModel(emb_size=EMBEDDING_DIM, dict_size=len(emb_dict), hid_size=HIDDEN_STATE_SIZE)
net.load_state_dict(torch.load(model_path))

end_token = emb_dict[END_TOKEN]

seq_count = 0
sum_bleu = 0.0

for seq_1, targets in train_data:
    input_seq = pack_input(seq_1, net.emb)
    enc = net.encode(input_seq)
    _, tokens = net.decode_chain_argmax(enc, input_seq.data[0:1],
                                        seq_len=MAX_TOKENS, stop_at_token=end_token)
    references = [seq[1:] for seq in targets]
    bleu = calc_bleu_many(tokens, references)
    sum_bleu += bleu
    seq_count += 1

log.info("Processed %d phrases, mean BLEU = %.4f", seq_count, sum_bleu / seq_count)
# Out:
# 2021-06-23 10:24:58,048 INFO Loaded 159 movies with genre comedy
# 2021-06-23 10:24:58,049 INFO Read and tokenise phrases...
# 2021-06-23 10:25:05,956 INFO Loaded 93039 phrases
# 2021-06-23 10:25:06,023 INFO Loaded 4445 dialogues with 17107 phrases, generating training pairs
# 2021-06-23 10:25:06,083 INFO Counting freq of words...
# 2021-06-23 10:25:06,131 INFO Data has 11807 uniq words, 1442 of them occur more than 10
# 2021-06-23 10:25:06,170 INFO Obtained 8885 phrase pairs with 1441 uniq words
# 2021-06-23 10:25:16,668 INFO Processed 2730 phrases, mean BLEU = 0.9478

# %%
# USER TEST
import os
import argparse
import logging

import torch

log = logging.getLogger("use")

def words_to_words(words, emb_dict, rev_emb_dict, net, use_sampling=False):
    tokens = encode_words(words, emb_dict)
    input_seq = pack_input(tokens, net.emb)
    enc = net.encode(input_seq)
    end_token = emb_dict[END_TOKEN]
    if use_sampling:
        _, out_tokens = net.decode_chain_sampling(enc, input_seq.data[0:1], seq_len=MAX_TOKENS,
                                                  stop_at_token=end_token)
    else:
        _, out_tokens = net.decode_chain_argmax(enc, input_seq.data[0:1], seq_len=MAX_TOKENS,
                                                stop_at_token=end_token)
    if out_tokens[-1] == end_token:
        out_tokens = out_tokens[:-1]
    out_words = decode_words(out_tokens, rev_emb_dict)
    return out_words


def process_string(s, emb_dict, rev_emb_dict, net, use_sampling=False):
    out_words = words_to_words(words, emb_dict, rev_emb_dict, net, use_sampling=use_sampling)
    print(" ".join(out_words))


# run live test
logging.basicConfig(format="%(asctime)-15s %(levelname)s %(message)s", level=logging.INFO)
data_genre = "comedy"
dictionary_path = "data/comedy_conversations/"
cuda_available = True 
name_of_the_run = 'comedy_conversations'
model_path = "data/comedy_conversations/epoch_160_0.991_0.108.dat"
device = torch.device("cuda" if cuda_available else "cpu")
sampling_enabled = False # Enable sampling generation instead of argmax
current_string_to_process = "" # String to process, otherwise will loop
self_loop_length = 1 # Enable self-loop mode with given amount of phrases."


emb_dict = load_emb_dict(os.path.dirname(dictionary_path))
net = PhraseModel(emb_size=EMBEDDING_DIM, dict_size=len(emb_dict), hid_size=HIDDEN_STATE_SIZE)
net.load_state_dict(torch.load(model_path))

rev_emb_dict = {idx: word for word, idx in emb_dict.items()}

while True:
    if current_string_to_process:
        input_string = current_string_to_process
    else:
        input_string = input(">>> ")
    if not input_string:
        break

    words = tokenize(input_string)
    for _ in range(self_loop_length):
        words = words_to_words(words, emb_dict, rev_emb_dict, net, use_sampling=sampling_enabled)
        print(untokenize(words))

    if current_string_to_process:
        break
pass
# Out:
# >>>  hey, how are you doing ?
# not exactly, it.
# >>>  oh, that sounds funny actually :)
# i don't want you to say this on.
# >>>  ha ?
# you never take him.
# >>>  true.
# it's none of your business.
# >>>  maybe not. i guess.
# oh, what did you say?
# >>>  maybe not, i said!
# i? oh to no!
# >>>  yes.
# here.
# >>>

# %% [markdown]
# # TODO's
#
# 1. Send your finished presentations (+ possibly annotated paper) by **Monday 12.00 AM/midnight** via email to henrik.voigt@uni-jena.de
#
# ***
